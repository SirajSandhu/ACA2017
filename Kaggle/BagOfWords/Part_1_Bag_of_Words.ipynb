# %%
import pandas as pd
train = pd.read_csv("labeledTrainData.tsv", header=0, delimiter="\t", quoting=3)

# %%
train.columns.values
# Out:
# array(['id', 'sentiment', 'review'], dtype=object)

# %%
from bs4 import BeautifulSoup
import re

# %%
import nltk
# nltk.download() #download text data set, including stop words

# %%
from nltk.corpus import stopwords

# %%
print stopwords.words("english")
# Out:
# [u'i', u'me', u'my', u'myself', u'we', u'our', u'ours', u'ourselves', u'you', u'your', u'yours', u'yourself', u'yourselves', u'he', u'him', u'his', u'himself', u'she', u'her', u'hers', u'herself', u'it', u'its', u'itself', u'they', u'them', u'their', u'theirs', u'themselves', u'what', u'which', u'who', u'whom', u'this', u'that', u'these', u'those', u'am', u'is', u'are', u'was', u'were', u'be', u'been', u'being', u'have', u'has', u'had', u'having', u'do', u'does', u'did', u'doing', u'a', u'an', u'the', u'and', u'but', u'if', u'or', u'because', u'as', u'until', u'while', u'of', u'at', u'by', u'for', u'with', u'about', u'against', u'between', u'into', u'through', u'during', u'before', u'after', u'above', u'below', u'to', u'from', u'up', u'down', u'in', u'out', u'on', u'off', u'over', u'under', u'again', u'further', u'then', u'once', u'here', u'there', u'when', u'where', u'why', u'how', u'all', u'any', u'both', u'each', u'few', u'more', u'most', u'other', u'some', u'such', u'no', u'nor', u'not', u'only', u'own', u'same', u'so', u'than', u'too', u'very', u's', u't', u'can', u'will', u'just', u'don', u'should', u'now', u'd', u'll', u'm', u'o', u're', u've', u'y', u'ain', u'aren', u'couldn', u'didn', u'doesn', u'hadn', u'hasn', u'haven', u'isn', u'ma', u'mightn', u'mustn', u'needn', u'shan', u'shouldn', u'wasn', u'weren', u'won', u'wouldn']

# %%
def review_to_words (raw_review) : 
    #the input and output are a single string 
    #
    # remove html
    review_text = BeautifulSoup(raw_review).get_text()
    #
    #remove non-alphabets
    letters_only = re.sub("[^a-zA-Z]", " ", review_text)
    #
    #lower case, split into words for the removal of stopwords
    words = letters_only.lower().split()
    #
    #In Python, searching a set is much faster than searching a list, so convert the stop words to a set
    stops = set(stopwords.words("english"))
    #
    #remove stop words
    meaningful_words = [w for w in words if not w in stops]
    #
    #join back to single string
    return(" ".join(meaningful_words))

# %%
clean_review = review_to_words(train["review"][1])
print clean_review
# Out:
# classic war worlds timothy hines entertaining film obviously goes great effort lengths faithfully recreate h g wells classic book mr hines succeeds watched film appreciated fact standard predictable hollywood fare comes every year e g spielberg version tom cruise slightest resemblance book obviously everyone looks different things movie envision amateur critics look criticize everything others rate movie important bases like entertained people never agree critics enjoyed effort mr hines put faithful h g wells classic novel found entertaining made easy overlook critics perceive shortcomings
# /usr/lib/python2.7/dist-packages/bs4/__init__.py:181: UserWarning: No parser was explicitly specified, so I'm using the best available HTML parser for this system ("lxml"). This usually isn't a problem, but if you run this code on another system, or in a different virtual environment, it may use a different parser and behave differently.
#
# The code that caused this warning is on line 174 of the file /usr/lib/python2.7/runpy.py. To get rid of this warning, change code that looks like this:
#
#  BeautifulSoup([your markup])
#
# to this:
#
#  BeautifulSoup([your markup], "lxml")
#
#   markup_type=markup_type))

# %%
# stemming
from nltk.stem import PorterStemmer
stemmer = PorterStemmer()

def stem_review (clean_review) :
    words = clean_review.split()
    stemmed_words = [stemmer.stem(w) for w in words if w!="oed"]
        # singular exception in entire dataset
    return (" ".join(stemmed_words))

# %%
stemmed_review = stem_review(clean_review)
print stemmed_review
# Out:
# classic war world timothi hine entertain film obvious goe great effort length faith recreat h g well classic book mr hine succe watch film appreci fact standard predict hollywood fare come everi year e g spielberg version tom cruis slightest resembl book obvious everyon look differ thing movi envis amateur critic look critic everyth other rate movi import base like entertain peopl never agre critic enjoy effort mr hine put faith h g well classic novel found entertain made easi overlook critic perceiv shortcom

# %%
num_reviews = train["review"].size

#initialising an empty list
clean_train_reviews = []

for i in xrange(0, num_reviews) : 
    clean_train_reviews.append(review_to_words(train["review"][i]))

# %%
stemmed_train_reviews = []

for i in xrange(0, num_reviews) :
    stemmed_train_reviews.append(stem_review(clean_train_reviews[i]))

# %%
from sklearn.feature_extraction.text import CountVectorizer

vectorizer = CountVectorizer(analyzer = "word", tokenizer = None, preprocessor = None,stop_words = None, \
                             max_features = 5000) 
# max_features is the max number of words to be included in the vector model; the vector will consist of 
# the 5000(=max_features) most frequent words

# fit_transform() does two functions: 
# First, it fits the model and learns the vocabulary
# Second, it transforms our training data into feature vectors. 
# The input to fit_transform should be a list of strings.

train_data_features = vectorizer.fit_transform(stemmed_train_reviews)

# Numpy arrays are easy to work with, so convert the result to an array
train_data_features = train_data_features.toarray()

# %%
from sklearn.feature_extraction.text import TfidfTransformer

tfidf_transformer = TfidfTransformer(norm="l2")
TfIdf_train_data_features = tfidf_transformer.fit_transform(train_data_features)
TfIdf_train_data_features = TfIdf_train_data_features.toarray()

# %%
print train_data_features.shape
# Out:
# (25000, 5000)

# %%
print TfIdf_train_data_features.shape
# Out:
# (25000, 5000)

# %%
vocab = vectorizer.get_feature_names()
print vocab
# Out:
# [u'abandon', u'abc', u'abil', u'abl', u'abomin', u'aborigin', u'abort', u'abound', u'abraham', u'abrupt', u'abruptli', u'absenc', u'absent', u'absolut', u'absorb', u'absurd', u'abund', u'abus', u'abysm', u'academi', u'accent', u'accept', u'access', u'accid', u'accident', u'acclaim', u'accompani', u'accomplish', u'accord', u'account', u'accur', u'accuraci', u'accus', u'ace', u'achiev', u'acid', u'acknowledg', u'acquaint', u'acquir', u'across', u'act', u'action', u'activ', u'actor', u'actress', u'actual', u'ad', u'adam', u'adapt', u'add', u'addict', u'addit', u'address', u'adequ', u'admir', u'admit', u'admittedli', u'adolesc', u'adopt', u'ador', u'adult', u'advanc', u'advantag', u'adventur', u'advertis', u'advic', u'advis', u'aesthet', u'affair', u'affect', u'affleck', u'afford', u'aforement', u'afraid', u'africa', u'african', u'afternoon', u'afterward', u'age', u'agenc', u'agenda', u'agent', u'aggress', u'ago', u'agre', u'ah', u'ahead', u'aid', u'aim', u'air', u'airplan', u'airport', u'aka', u'akin', u'akshay', u'al', u'ala', u'alan', u'alarm', u'albeit', u'albert', u'album', u'alcohol', u'alec', u'alert', u'alex', u'alexand', u'alexandr', u'alfr', u'alic', u'alicia', u'alien', u'alik', u'alison', u'aliv', u'alleg', u'allen', u'alley', u'alli', u'allow', u'almost', u'alon', u'along', u'alongsid', u'alreadi', u'alright', u'also', u'alter', u'altern', u'although', u'altman', u'altogeth', u'alvin', u'alway', u'amanda', u'amateur', u'amateurish', u'amaz', u'amazingli', u'amazon', u'ambigu', u'ambit', u'ambiti', u'america', u'american', u'ami', u'amitabh', u'among', u'amongst', u'amor', u'amount', u'amrita', u'amus', u'analysi', u'analyz', u'anchor', u'ancient', u'anderson', u'andi', u'andr', u'andrew', u'angel', u'angela', u'anger', u'angl', u'angri', u'angst', u'anim', u'ann', u'anna', u'anni', u'announc', u'annoy', u'anoth', u'answer', u'ant', u'antagonist', u'antholog', u'anthoni', u'anti', u'antic', u'anticip', u'anton', u'antonio', u'antonioni', u'antwon', u'anybodi', u'anyhow', u'anymor', u'anyon', u'anyth', u'anyway', u'anywher', u'apart', u'ape', u'apolog', u'appal', u'appar', u'appeal', u'appear', u'appl', u'applaud', u'appli', u'appreci', u'approach', u'appropri', u'approv', u'april', u'arab', u'arc', u'archiv', u'area', u'argu', u'arguabl', u'argument', u'ariel', u'aris', u'aristocrat', u'arm', u'armi', u'armstrong', u'arnold', u'around', u'arrang', u'arrest', u'arriv', u'arrog', u'arrow', u'art', u'arthur', u'articl', u'artifici', u'artist', u'artsi', u'artwork', u'ash', u'asham', u'ashley', u'asian', u'asid', u'ask', u'asleep', u'aspect', u'aspir', u'ass', u'assassin', u'assault', u'assembl', u'assert', u'asset', u'assign', u'assist', u'associ', u'assort', u'assum', u'assur', u'astair', u'astonish', u'astound', u'astronaut', u'asylum', u'athlet', u'atlanti', u'atmospher', u'atroc', u'atroci', u'attach', u'attack', u'attempt', u'attenborough', u'attend', u'attent', u'attitud', u'attorney', u'attract', u'attribut', u'audienc', u'audio', u'audit', u'audrey', u'aunt', u'aussi', u'austen', u'austin', u'australia', u'australian', u'authent', u'author', u'automat', u'avail', u'aveng', u'averag', u'avoid', u'aw', u'await', u'awak', u'awaken', u'awar', u'award', u'away', u'awe', u'awesom', u'awhil', u'awkward', u'axe', u'babe', u'babi', u'bacal', u'bach', u'bachelor', u'back', u'backdrop', u'background', u'backward', u'bacon', u'bad', u'baddi', u'badli', u'baffl', u'bag', u'bait', u'bake', u'baker', u'bakshi', u'balanc', u'baldwin', u'ball', u'ballet', u'ban', u'banal', u'band', u'bang', u'bank', u'banter', u'bar', u'barbara', u'bare', u'bargain', u'barn', u'barrel', u'barri', u'barrymor', u'base', u'basebal', u'basement', u'bash', u'basi', u'basic', u'basing', u'basket', u'basketbal', u'bastard', u'bat', u'bate', u'bath', u'bathroom', u'batman', u'battl', u'bay', u'bbc', u'be', u'beach', u'bean', u'bear', u'beard', u'beast', u'beat', u'beaten', u'beatl', u'beatti', u'beauti', u'becam', u'becom', u'bed', u'bedroom', u'beer', u' ...

# %%
import numpy as np

# Sum up the counts of each vocabulary word
dist = np.sum(train_data_features, axis=0)

# For each, print the vocabulary word and the number of times it 
# appears in the training set
for tag, count in zip(vocab, dist):
    print count, tag
# Out:
# 288 abandon
# 125 abc
# 562 abil
# 1259 abl
# 83 abomin
# 69 aborigin
# 92 abort
# 63 abound
# 93 abraham
# 76 abrupt
# 60 abruptli
# 118 absenc
# 83 absent
# 1845 absolut
# 154 absorb
# 403 absurd
# 66 abund
# 398 abus
# 110 abysm
# 298 academi
# 704 accent
# 781 accept
# 165 access
# 344 accid
# 246 accident
# 118 acclaim
# 197 accompani
# 271 accomplish
# 311 accord
# 297 account
# 349 accur
# 82 accuraci
# 204 accus
# 75 ace
# 578 achiev
# 102 acid
# 109 acknowledg
# 73 acquaint
# 97 acquir
# 971 across
# 8794 act
# 3694 action
# 268 activ
# 6876 actor
# 1588 actress
# 5065 actual
# 793 ad
# 409 adam
# 835 adapt
# 1147 add
# 261 addict
# 499 addit
# 183 address
# 148 adequ
# 440 admir
# 738 admit
# 134 admittedli
# 112 adolesc
# 162 adopt
# 226 ador
# 887 adult
# 275 advanc
# 172 advantag
# 773 adventur
# 228 advertis
# 262 advic
# 195 advis
# 78 aesthet
# 419 affair
# 428 affect
# 66 affleck
# 139 afford
# 126 aforement
# 343 afraid
# 212 africa
# 284 african
# 197 afternoon
# 183 afterward
# 1726 age
# 79 agenc
# 86 agenda
# 455 agent
# 103 aggress
# 1033 ago
# 779 agre
# 119 ah
# 396 ahead
# 289 aid
# 325 aim
# 842 air
# 106 airplan
# 96 airport
# 195 aka
# 67 akin
# 125 akshay
# 379 al
# 208 ala
# 351 alan
# 86 alarm
# 157 albeit
# 265 albert
# 116 album
# 225 alcohol
# 81 alec
# 103 alert
# 232 alex
# 122 alexand
# 67 alexandr
# 103 alfr
# 199 alic
# 79 alicia
# 702 alien
# 154 alik
# 86 alison
# 464 aliv
# 64 alleg
# 408 allen
# 79 alley
# 136 alli
# 1026 allow
# 3139 almost
# 1066 alon
# 1777 along
# 90 alongsid
# 1381 alreadi
# 185 alright
# 9156 also
# 168 alter
# 247 altern
# 2537 although
# 114 altman
# 112 altogeth
# 70 alvin
# 3243 alway
# 101 amanda
# 252 amateur
# 222 amateurish
# 1563 amaz
# 174 amazingli
# 77 amazon
# 141 ambigu
# 118 ambit
# 129 ambiti
# 738 america
# 2618 american
# 120 ami
# 93 amitabh
# 783 among
# 160 amongst
# 71 amor
# 597 amount
# 61 amrita
# 710 amus
# 88 analysi
# 72 analyz
# 82 anchor
# 237 ancient
# 225 anderson
# 347 andi
# 99 andr
# 298 andrew
# 512 angel
# 85 angela
# 226 anger
# 399 angl
# 337 angri
# 72 angst
# 2483 anim
# 542 ann
# 251 anna
# 125 anni
# 153 announc
# 1262 annoy
# 4326 anoth
# 626 answer
# 110 ant
# 70 antagonist
# 67 antholog
# 263 anthoni
# 480 anti
# 117 antic
# 175 anticip
# 68 anton
# 63 antonio
# 82 antonioni
# 89 antwon
# 311 anybodi
# 60 anyhow
# 333 anymor
# 2632 anyon
# 2949 anyth
# 1230 anyway
# 304 anywher
# 995 apart
# 222 ape
# 107 apolog
# 163 appal
# 1226 appar
# 748 appeal
# 2567 appear
# 64 appl
# 102 applaud
# 170 appli
# 852 appreci
# 552 approach
# 309 appropri
# 88 approv
# 103 april
# 103 arab
# 95 arc
# 69 archiv
# 453 area
# 210 argu
# 95 arguabl
# 180 argument
# 71 ariel
# 67 aris
# 77 aristocrat
# 425 arm
# 474 armi
# 64 armstrong
# 148 arnold
# 3616 around
# 146 arrang
# 211 arrest
# 514 arriv
# 147 arrog
# 78 arrow
# 1653 art
# 374 arthur
# 67 articl
# 124 artifici
# 897 artist
# 74 artsi
# 68 artwork
# 63 ash
# 161 asham
# 89 ashley
# 260 asian
# 486 asid
# 1500 ask
# 213 asleep
# 852 aspect
# 159 aspir
# 290 ass
# 223 assassin
# 132 assault
# 107 assembl
# 70 assert
# 62 asset
# 168 assign
# 278 assist
# 257 associ
# 62 assort
# 423 assum
# 143 assur
# 132 astair
# 114 astonish
# 72 astound
# 70 astronaut
# 78 asylum
# 73 athlet
# 111 atlanti
# 901 atmospher
# 76 atroc
# 208 atroci
# 193 attach
# 864 attack
# 1932 attempt
# 75 attenborough
# 279 attend
# 940 attent
# 327 attitud
# 95 attorney
# 749 attract
# 88 attribut
# 2675 audienc
# 113 audio
# 110 audit
# 66 audrey
# 204 aunt
# 63 aussi
# 92 austen
# 82 austin
# 126 australia
# 223 australian
# 238 authent
# 494 author
# 118 automat
# 419 avail
# 106 aveng
# 731 averag
# 994 avoid
# 1861 aw
# 111 await
# 116 awak
# 119 awaken
# 326 awar
# 712 award
# 2782 away
# 119 awe
# 510 awesom
# 78 awhil
# 264 awkward
# 68 axe
# 144 babe
# 770 babi
# 90 bacal
# 62 bach
# 69 bachelor
# 5133 back
# 141 backdrop
# 720 background
# 92 backward
# 78 bacon
# 9344 bad
# 88 baddi
# 662 badli
# 73 baffl
# 186 bag
# 63 bait
# 81 bake
# 159 baker
# 132 bakshi
# 256 balanc
# 83 baldwin
# 388 ball
# 99 ballet
# 142 ban
# 95 banal
# 627 band
# 153 bang
# 318 bank
# 68 banter
# 478 bar
# 243 barbara
# 621 bare
# 110 bargain
# 69 barn
# 87 barrel
# 147 barri
# 88 barrymor
# 1645 base
# 217 basebal
# 145 basement
# 125 bash
# 170 basi
# 1453 basic
# 77 basing
# 63 basket
# 88 basketbal
# 65 bastard
# 223 bat
# 68 bate
# 161 bath
# 117 bathroom
# 434 batman
# 795 battl
# 93 bay
# 189 bbc
# 130 be
# 216 beach
# 74 bean
# 445 bear
# 70 beard
# 205 beast
# 619 beat
# 124 beaten
# 85 beatl
# 115 beatti
# 3292 beauti
# 697 becam
# 3272 becom
# 415 bed
# 112 bedroom
# 168 beer
# 111 befriend
# 182 beg
# 318 began
# 2905 begin
# 191 behav
# 296 behavior
# 78 behaviour
# 1280 behind
# 81 behold
# 94 bela
# 280 belief
# 3917 believ
# 186 bell
# 64 belli
# 286 belong
# 178 belov
# 95 belt
# 87 belushi
# 619 ben
# 92 bend
# 104 beneath
# 175 benefit
# 71 bent
# 61 beowulf
# 97 bergman
# 101 berlin
# 75 bernard
# 481 besid
# 6424 best
# 287 bet
# 187 betray
# 157 bett
# 5749 better
# 254 betti
# 76 beverli
# 73 bewar
# 866 beyond
# 80 bias
# 139 bibl
# 68 biblic
# 3477 big
# 268 bigger
# 515 biggest
# 89 bike
# 72 biker
# 67 bikini
# 89 biko
# 799 bill
# 407 billi
# 118 bin
# 99 biographi
# 61 biopic
# 229 bird
# 204 birth
# 140 birthday
# 3349 bit
# 100 bitch
# 214 bite
# 69 bitten
# 184 bitter
# 529 bizarr
# 2123 black
# 89 blackmail
# 115 blade
# 195 blah
# 168 blair
# 115 blake
# 394 blame
# 334 bland
# 153 blank
# 130 blast
# 104 blatant
# 67 blatantli
# 127 bleak
# 96 bleed
# 200 blend
# 120 bless
# 101 blew
# 322 blind
# 124 blob
# 166 block
# 235 blockbust
# 390 blond
# 1245 blood
# 314 bloodi
# 79 bloom
# 436 blow
# 184 blown
# 531 blue
# 98 blunt
# 63 blur
# 157 bo
# 330 board
# 115 boast
# 283 boat
# 279 bob
# 148 bobbi
# 1199 bodi
# 65 bogu
# 124 boil
# 110 bold
# 145 boll
# 169 bollywood
# 385 bomb
# 419 bond
# 67 bondag
# 183 bone
# 97 bonu
# 65 boo
# 69 boob
# 2935 book
# 102 boom
# 149 boot
# 61 booth
# 205 border
# 2549 bore
# 142 boredom
# 64 bori
# 400 born
# 190 borrow
# 468 boss
# 71 boston
# 655 bother
# 113 bottl
# 436 bottom
# 458 bought
# 73 bounc
# 204 bound
# 192 bourn
# 97 bow
# 105 bowl
# 813 box
# 88 boxer
# 2178 boy
# 66 boyer
# 433 boyfriend
# 79 boyl
# 176 brad
# 110 bradi
# 601 brain
# 186 branagh
# 148 brand
# 159 brando
# 227 brave
# 65 braveheart
# 62 bravo
# 116 brazil
# 76 bread
# 1101 break
# 65 breakdown
# 67 breakfast
# 192 breast
# 303 breath
# 168 breathtak
# 103 breed
# 84 brenda
# 73 brendan
# 352 brian
# 185 bride
# 227 bridg
# 80 bridget
# 403 brief
# 135 briefli
# 284 bright
# 130 brillianc
# 1196 brilliant
# 248 brilliantli
# 1715 bring
# 76 brit
# 153 britain
# 901 british
# 84 bro
# 119 broad
# 160 broadcast
# 243 broadway
# 151 broke
# 278 broken
# 73 bronson
# 61 bront
# 74 brood
# 234 brook
# 106 brooklyn
# 128 brosnan
# 1664 brother
# 737 brought
# 310 brown
# 393 bruce
# 60 bruno
# 69 brush
# 485 brutal
# 63 bsg
# 65 btw
# 199 bu
# 104 bubbl
# 306 buck
# 134 bud
# 367 buddi
# 1933 budget
# 200 buff
# 89 buffalo
# 285 bug
# 921 build
# 236 built
# 64 bulk
# 113 bull
# 233 bullet
# 161 bulli
# 97 bumbl
# 89 bump
# 819 bunch
# 87 bunni
# 190 buri
# 61 burk
# 570 burn
# 132 burst
# 167 burt
# 153 burton
# 150 bush
# 802 busi
# 83 businessman
# 111 bust
# 84 buster
# 60 butch
# 128 butcher
# 88 butler
# 148 butt
# 138 button
# 1007 buy
# 74 buzz
# 74 bye
# 180 cabin
# 285 cabl
# 334 cage
# 124 cagney
# 266 cain
# 107 cake
# 84 calib
# 189 california
# 2792 call
# 93 calm
# 71 camcord
# 1673 came
# 406 cameo
# 1888 camera
# 124 cameron
# 546 camp
# 85 campaign
# 97 campbel
# 195 campi
# 139 canada
# 242 canadian
# 155 cancel
# 76 cancer
# 293 candi
# 115 candid
# 72 candl
# 155 cannib
# 91 cannon
# 1096 cannot
# 207 cant
# 80 canyon
# 78 cap
# 284 capabl
# 63 cape
# 174 capit
# 64 capot
# 341 captain
# 245 captiv
# 852 captur
# 1505 car
# 249 card
# 132 cardboard
# 2124 care
# 1116 career
# 90 carel
# 69 carey
# 109 cari
# 148 caricatur
# 110 carl
# 87 carla
# 74 carlito
# 68 carlo
# 63 carmen
# 177 carol
# 167 carpent
# 96 carradin
# 133 carrey
# 940 carri
# 151 carter
# 753 cartoon
# 66 cartoonish
# 1706 case
# 258 cash
# 68 casino
# 62 casper
# 71 cassavet
# 85 cassidi
# 4573 cast
# 357 castl
# 103 casual
# 657 cat
# 647 catch
# 91 catchi
# 252 categori
# 143 catherin
# 168 cathol
# 75 cattl
# 555 caught
# 1044 caus
# 128 cave
# 78 cb
# 109 cd
# 64 cecil
# 378 celebr
# 222 cell
# 108 celluloid
# 65 cemeteri
# 83 censor
# 91 cent
# 446 center
# 110 centr
# 415 central
# 580 centuri
# 67 cerebr
# 66 ceremoni
# 764 certain
# 1462 certainli
# 97 cg
# 329 cgi
# 180 chain
# 78 chainsaw
# 181 chair
# 428 challeng
# 76 chamberlain
# 95 champion
# 85 championship
# 225 chan
# 1204 chanc
# 2062 chang
# 550 channel
# 110 chao
# 152 chaplin
# 124 chapter
# 14178 charact
# 206 character
# 74 characteris
# 109 characterist
# 308 charg
# 138 charisma
# 135 charismat
# 409 charl
# 446 charli
# 98 charlott
# 66 charlton
# 965 charm
# 824 chase
# 76 chavez
# 217 che
# 61 cheadl
# 903 cheap
# 258 cheat
# 1011 check
# 126 cheek
# 241 cheer
# 164 chees
# 674 cheesi
# 490 chemistri
# 68 cher
# 96 chess
# 107 chest
# 126 chew
# 92 chicago
# 322 chick
# 94 chicken
# 237 chief
# 1324 child
# 360 childhood
# 120 childish
# 1515 children
# 304 chill
# 188 china
# 338 chines
# 65 chip
# 699 choic
# 67 choke
# 378 choos
# 163 chop
# 76 choppi
# 145 choreograph
# 116 choreographi
# 99 choru
# 203 chose
# 232 chosen
# 421 chri
# 183 christ
# 165 christi
# 544 christian
# 73 christin
# 61 christina
# 623 christma
# 424 christoph
# 88 chronicl
# 155 chuck
# 150 chuckl
# 428 church
# 124 cia
# 79 cigarett
# 236 cinderella
# 1553 cinema
# 428 cinemat
# 157 cinematograph
# 983 cinematographi
# 166 circl
# 72 circu
# 248 circumst
# 1283 citi
# 200 citizen
# 273 civil
# 60 civilian
# 68 clad
# 595 claim
# 196 clair
# 75 clan
# 64 clara
# 283 clark
# 82 clash
# 1012 class
# 2159 classic
# 80 clau
# 69 claud
# 71 claustrophob
# 342 clean
# 818 clear
# 899 clearli
# 81 clerk
# 561 clever
# 94 cleverli
# 1047 clich
# 82 click
# 65 client
# 127 cliff
# 68 cliffhang
# 93 climact
# 84 climat
# 448 climax
# 150 climb
# 66 clinic
# 110 clint
# 263 clip
# 128 clock
# 93 clone
# 1744 close
# 206 closer
# 94 closest
# 128 closet
# 497 cloth
# 83 cloud
# 127 clown
# 466 club
# 347 clue
# 73 clueless
# 110 clumsi
# 60 clutter
# 647 co
# 129 coach
# 90 coast
# 77 coaster
# 107 coat
# 266 code
# 107 coffe
# 70 cohen
# 157 coher
# 131 coincid
# 577 cold
# 134 cole
# 68 colin
# 114 collabor
# 108 collaps
# 106 colleagu
# 562 collect
# 65 collector
# 509 colleg
# 106 colonel
# 116 coloni
# 827 color
# 248 colour
# 208 columbo
# 231 com
# 63 comb
# 123 combat
# 629 combin
# 6747 come
# 319 comed
# 3686 comedi
# 236 comedian
# 259 comfort
# 1230 comic
# 287 command
# 99 commend
# 1687 comment
# 347 commentari
# 392 commerci
# 490 commit
# 515 common
# 555 commun
# 127 communist
# 596 compani
# 137 companion
# 1068 compar
# 320 comparison
# 97 compass
# 491 compel
# 97 compens
# 294 compet
# 164 competit
# 268 complain
# 216 complaint
# 3035 complet
# 548 complex
# 279 complic
# 91 compliment
# 241 compos
# 98 composit
# 66 comprehend
# 63 comprehens
# 65 compris
# 83 compromis
# 541 comput
# 267 con
# 63 conan
# 168 conceiv
# 190 concentr
# 627 concept
# 621 concern
# 165 concert
# 151 conclud
# 539 conclus
# 87 condemn
# 251 condit
# 81 conduct
# 190 confess
# 194 confid
# 98 confin
# 114 confirm
# 425 conflict
# 287 confront
# 959 confus
# 63 congratul
# 656 connect
# 94 conneri
# 79 connor
# 70 conquer
# 65 conrad
# 77 conscienc
# 79 consciou
# 80 conscious
# 228 consequ
# 115 conserv
# 1585 consid
# 235 consider
# 491 consist
# 146 conspiraci
# 292 constant
# 416 constantli
# 64 constitut
# 252 construct
# 106 consum
# 200 contact
# 765 contain
# 96 contempl
# 236 contemporari
# 71 contempt
# 61 contend
# 414 content
# 200 contest
# 264 context
# 1159 continu
# 156 contract
# 84 contradict
# 116 contrari
# 305 contrast
# 256 contribut
# 268 contriv
# 697 control
# 210 controversi
# 130 conveni
# 296 convent
# 357 convers
# 75 convert
# 341 convey
# 233 convict
# 1012 convinc
# 93 convincingli
# 128 convolut
# 247 cook
# 84 cooki
# 998 cool
# 201 cooper
# 934 cop
# 105 cope
# 741 copi
# 71 corbett
# 259 core
# 70 corman
# 65 corn
# 197 corner
# 263 corni
# 197 corpor
# 200 corps
# 305 correct
# 82 correctli
# 265 corrupt
# 457 cost
# 689 costum
# 76 couch
# 7922 could
# 507 count
# 101 counter
# 76 counterpart
# 136 countless
# 1086 countri
# 103 countrysid
# 85 coup
# 1894 coupl
# 192 courag
# 2520 cours
# 229 court
# 186 cousin
# 927 cover
# 70 cow
# 243 cowboy
# 132 cox
# 253 crack
# 306 craft
# 123 craig
# 1054 crap
# 248 crappi
# 361 crash
# 123 craven
# 83 crawford
# 84 crawl
# 101 craze
# 699 crazi
# 84 cream
# 1683 creat
# 174 creation
# 474 creativ
# 219 creator
# 554 creatur
# 316 credibl
# 1295 credit
# 64 creek
# 163 creep
# 673 creepi
# 584 crew
# 770 cri
# 896 crime
# 537 crimin
# 174 cring
# 81 crippl
# 153 crisi
# 61 crisp
# 1071 critic
# 80 critiqu
# 111 crocodil
# 117 crook
# 61 crosbi
# 494 cross
# 84 crow
# 302 crowd
# 85 crown
# 90 crucial
# 206 crude
# 183 cruel
# 74 cruelti
# 145 cruis
# 190 crush
# 93 crystal
# 109 cuba
# 65 cuban
# 151 cube
# 104 cue
# 79 culmin
# 502 cult
# 762 cultur
# 136 cup
# 138 cure
# 124 curios
# 262 curiou
# 76 curli
# 379 current
# 231 curs
# 63 curtain
# 142 curti
# 141 cusack
# 70 cush
# 118 custom
# 1520 cut
# 604 cute
# 89 cyborg
# 68 cycl
# 232 cynic
# 62 cypher
# 96 da
# 511 dad
# 109 daddi
# 168 daili
# 89 daisi
# 97 dalton
# 204 damag
# 68 dame
# 89 damm
# 438 damn
# 90 damon
# 301 dan
# 83 dana
# 1405 danc
# 265 dancer
# 72 dandi
# 149 dane
# 587 danger
# 339 daniel
# 69 danish
# 347 danni
# 306 dare
# 1573 dark
# 117 darker
# 81 darn
# 83 darren
# 125 dash
# 883 date
# 1312 daughter
# 124 dave
# 495 davi
# 1025 david
# 157 dawn
# 133 dawson
# 4014 day
# 95 dazzl
# 792 de
# 1883 dead
# 201 deadli
# 90 deaf
# 1260 deal
# 99 dealer
# 137 dealt
# 192 dean
# 148 dear
# 2113 death
# 126 debat
# 81 debt
# 292 debut
# 476 decad
# 63 decapit
# 82 deceas
# 1178 decent
# 73 decept
# 1786 decid
# 353 decis
# 127 declar
# 101 declin
# 111 decor
# 152 dedic
# 82 dee
# 97 deed
# 66 deem
# 658 deep
# 177 deeper
# 320 deepli
# 69 deer
# 219 defeat
# 195 defend
# 102 defens
# 115 defi
# 246 defin
# 1856 definit
# 87 degrad
# 256 degre
# 97 del
# 78 delet
# 171 deliber
# 83 delic
# 113 delici
# 564 delight
# 1021 deliv
# 65 deliver
# 189 deliveri
# 79 delv
# 294 demand
# 90 dement
# 83 demis
# 446 demon
# 249 demonstr
# 222 deni
# 82 deniro
# 193 denni
# 168 dentist
# 143 denzel
# 277 depart
# 69 departur
# 252 depend
# 663 depict
# 482 depress
# 570 depth
# 61 deputi
# 91 der
# 83 derang
# 155 derek
# 139 deriv
# 105 descend
# 91 descent
# 728 describ
# 212 descript
# 351 desert
# 1236 deserv
# 745 design
# 500 desir
# 97 despair
# 608 desper
# 73 despic
# 80 despis
# 1364 despit
# 126 destin
# 113 destini
# 569 destroy
# 212 destruct
# 62 detach
# 884 detail
# 561 detect
# 277 determin
# 114 detract
# 106 devast
# 1595 develop
# 256 devic
# 346 devil
# 104 devoid
# 176 devot
# 915 dialog
# 1652 dialogu
# 153 diamond
# 105 dian
# 101 diana
# 74 diari
# 300 dick
# 101 dicken
# 90 dictat
# 2012 die
# 3007 differ
# 695 difficult
# 148 difficulti
# 216 dig
# 161 digit
# 120 digniti
# 72 dilemma
# 68 dim
# 110 dimens
# 267 dimension
# 84 din
# 157 dinner
# 210 dinosaur
# 125 dire
# 3794 direct
# 193 directli
# 5120 director
# 125 directori
# 76 dirt
# 337 dirti
# 105 disabl
# 151 disagre
# 355 disappear
# 1900 disappoint
# 356 disast
# 73 disastr
# 175 disbelief
# 139 disc
# 69 discern
# 849 discov
# 128 discoveri
# 397 discuss
# 157 diseas
# 102 disgrac
# 159 disguis
# 358 disgust
# 71 dish
# 103 disjoint
# 257 dislik
# 71 dismal
# 101 dismiss
# 756 disney
# 86 disord
# 464 display
# 92 dispos
# 66 disregard
# 139 distanc
# 124 distant
# 182 distinct
# 89 distinguish
# 85 distort
# 304 distract
# 83 distress
# 157 distribut
# 60 distributor
# 639 disturb
# 104 dive
# 131 divers
# 80 divid
# 69 divin
# 175 divorc
# 94 dixon
# 143 doc
# 704 doctor
# 144 document
# 1074 documentari
# 60 dodg
# 898 dog
# 203 doll
# 369 dollar
# 86 dolph
# 108 domest
# 276 domin
# 103 domino
# 191 donald
# 3096 done
# 116 donna
# 74 dont
# 124 doo
# 196 doom
# 557 door
# 142 dorothi
# 115 dose
# 433 doubl
# 887 doubt
# 315 dougla
# 70 down
# 79 downey
# 96 downhil
# 188 downright
# 299 dozen
# 702 dr
# 121 dracula
# 523 drag
# 245 dragon
# 97 drain
# 89 drake
# 1552 drama
# 799 dramat
# 471 draw
# 428 drawn
# 372 dread
# 1174 dream
# 89 dreari
# 81 dreck
# 636 dress
# 248 drew
# 266 dri
# 87 drift
# 382 drink
# 85 drip
# 872 drive
# 125 drivel
# 239 driven
# 230 driver
# 62 drone
# 524 drop
# 79 drove
# 138 drown
# 771 drug
# 97 drum
# 311 drunk
# 123 drunken
# 480 dub
# 62 dubiou
# 90 duck
# 104 dud
# 207 dude
# 66 dudley
# 918 due
# 75 duel
# 192 duke
# 836 dull
# 660 dumb
# 149 dump
# 124 duo
# 65 durat
# 97 dust
# 105 dutch
# 155 duti
# 94 duval
# 2411 dvd
# 70 dwarf
# 61 dwell
# 68 dylan
# 171 dynam
# 91 dysfunct
# 99 eager
# 205 ear
# 93 earl
# 1605 earli
# 662 earlier
# 235 earn
# 68 earnest
# 929 earth
# 118 eas
# 806 easi
# 132 easier
# 892 easili
# 171 east
# 85 eastern
# 139 eastwood
# 622 eat
# 90 eaten
# 71 ebert
# 128 eccentr
# 109 echo
# 91 econom
# 344 ed
# 347 eddi
# 517 edg
# 95 edgar
# 86 edgi
# 111 edi
# 1250 edit
# 144 editor
# 279 educ
# 233 edward
# 155 eeri
# 3581 effect
# 73 effici
# 1047 effort
# 74 egg
# 147 ego
# 222 eight
# 127 eighti
# 65 einstein
# 1866 either
# 77 el
# 147 elabor
# 119 elderli
# 135 elect
# 135 electr
# 67 electron
# 123 eleg
# 1176 element
# 141 eleph
# 169 elev
# 64 eleven
# 67 eli
# 109 elimin
# 77 elit
# 175 elizabeth
# 123 ellen
# 87 elm
# 2002 els
# 140 elsewher
# 154 elvi
# 155 elvira
# 158 em
# 64 embark
# 528 embarrass
# 60 embodi
# 106 embrac
# 240 emerg
# 125 emili
# 203 emma
# 1731 emot
# 84 empathi
# 97 emperor
# 88 emphas
# 101 emphasi
# 128 empir
# 217 employ
# 94 employe
# 307 empti
# 91 en
# 74 enabl
# 112 enchant
# 381 encount
# 187 encourag
# 9651 end
# 158 endear
# 235 endless
# 60 endlessli
# 219 endur
# 307 enemi
# 65 energet
# 324 energi
# 81 enforc
# 578 engag
# 148 engin
# 307 england
# 987 english
# 93 engross
# 172 enhanc
# 4353 enjoy
# 99 enlighten
# 72 enlist
# 149 enorm
# 3452 enough
# 152 ensembl
# 170 ensu
# 99 ensur
# 451 enter
# 113 enterpris
# 2828 entertain
# 75 enthral
# 86 enthusiasm
# 126 enthusiast
# 1993 entir
# 60 entireti
# 75 entitl
# 76 entranc
# 191 entri
# 199 environ
# 371 epic
# 2629 episod
# 62 epitom
# 642 equal
# 107 equip
# 90 equival
# 92 er
# 635 era
# 266 eric
# 208 erot
# 86 errol
# 171 error
# 889 escap
# 2539 especi
# 138 essenc
# 425 essenti
# 356 establish
# 137 estat
# 75 esther
# 67 estrang
# 103 et
# 1212 etc
# 154 etern
# 92 ethan
# 100 ethnic
# 91 eugen
# 216 europ
# 68 europa
# 340 european
# 140 eva
# 62 evan
# 119 eve
# 64 evelyn
# 12907 even
# 1293 event
# 782 eventu
# 6005 ever
# 3978 everi
# 413 everybodi
# 167 everyday
# 2228 everyon
# 2323 everyth
# 190 everywher
# 426 evid
# 1468 evil
# 127 evok
# 65 evolut
# 116 evolv
# 468 ex
# 201 exact
# 995 exactli
# 197 exagger
# 195 examin
# 1554 exampl
# 2253 excel
# 1854 except
# 211 excess
# 131 exchang
# 996 excit
# 82 exclus
# 503 excus
# 680 execut
# 145 exercis
# 80 exhaust
# 111 exhibit
# 1057 exist
# 97 exit
# 106 exot
# 92 expand
# 3007 expect
# 82 expedit
# 209 expens
# 1548 experi
# 249 experienc
# 102 experiment
# 218 expert
# 61 expertli
# 1042 explain
# 327 explan
# 120 explicit
# 174 explod
# 497 exploit
# 482 explor
# 293 explos
# 238 expos
# 84 exposit
# 88 exposur
# 702 express
# 86 exquisit
# 169 extend
# 93 extens
# 172 extent
# 73 exterior
# 543 extra
# 173 extraordinari
# 1473 extrem
# 2201 eye
# 116 eyr
# 81 fabric
# 187 fabul
# 2292 face
# 185 facial
# 74 facil
# 3750 fact
# 280 factor
# 151 factori
# 187 fade
# 1511 fail
# 290 failur
# 70 faint
# 503 fair
# 216 fairi
# 587 fairli
# 514 faith
# 533 fake
# 122 falk
# 2004 fall
# 165 fallen
# 213 fals
# 276 fame
# 3454 famili
# 572 familiar
# 771 famou
# 3371 fan
# 111 fanat
# 146 fanci
# 725 fantasi
# 855 fantast
# 2978 far
# 126 farc
# 241 fare
# 129 farm
# 99 farmer
# 97 farrel
# 81 fart
# 573 fascin
# 70 fascist
# 550 fashion
# 899 fast
# 100 faster
# 283 fat
# 227 fatal
# 344 fate
# 2207 father
# 344 fault
# 324 favor
# 1421 favorit
# 123 favour
# 376 favourit
# 165 fay
# 153 fbi
# 751 fear
# 67 feast
# 78 feat
# 1903 featur
# 92 fed
# 182 feed
# 5300 feel
# 236 feet
# 121 felix
# 357 fell
# 405 fellow
# 1528 felt
# 1022 femal
# 66 feminin
# 99 feminist
# 83 femm
# 82 fenc
# 147 fest
# 466 festiv
# 137 fetch
# 61 fetish
# 119 fever
# 661 fi
# 144 fianc
# 698 fiction
# 84 fido
# 376 field
# 127 fifteen
# 67 fifth
# 148 fifti
# 2040 fight
# 150 fighter
# 1190 figur
# 144 file
# 917 fill
# 77 filler
# 48191 film
# 959 filmmak
# 71 filth
# 60 filthi
# 3153 final
# 77 financ
# 142 financi
# 5449 find
# 1366 fine
# 278 finest
# 185 finger
# 809 finish
# 879 fire
# 86 firm
# 64 firmli
# 9062 first
# 90 firstli
# 241 fish
# 69 fishburn
# 129 fisher
# 131 fist
# 866 fit
# 938 five
# 168 fix
# 70 flag
# 79 flair
# 114 flame
# 266 flash
# 417 flashback
# 70 flashi
# 594 flat
# 67 flavor
# 659 flaw
# 126 flawless
# 90 flee
# 87 fleet
# 315 flesh
# 695 fli
# 1629 flick
# 188 flight
# 122 flip
# 70 flirt
# 146 float
# 69 flock
# 60 flood
# 324 floor
# 152 flop
# 107 florida
# 261 flow
# 124 flower
# 71 fluff
# 64 fluid
# 147 flynn
# 509 focu
# 491 focus
# 82 fog
# 67 foil
# 462 folk
# 2292 follow
# 132 fond
# 112 fonda
# 72 fontain
# 338 food
# 388 fool
# 71 foolish
# 285 foot
# 656 footag
# 226 footbal
# 120 forbidden
# 1534 forc
# 305 ford
# 275 foreign
# 208 forest
# 392 forev
# 821 forget
# 206 forgett
# 255 forgiv
# 63 forgiven
# 178 forgot
# 353 forgotten
# 957 form
# 215 format
# 509 former
# 370 formula
# 190 forth
# 156 forti
# 373 fortun
# 719 forward
# 205 foster
# 81 fought
# 117 foul
# 2608 found
# 60 foundat
# 915 four
# 178 fourth
# 368 fox
# 78 foxx
# 68 fragil
# 430 frame
# 290 franc
# 162 franchis
# 92 franci
# 123 francisco
# 98 franco
# 488 frank
# 92 frankenstein
# 94 franki
# 256 frankli
# 70 frantic
# 285 freak
# 303 fred
# 310 freddi
# 717 free
# 249 freedom
# 188 freeman
# 89 freez
# 790 french
# 256 frequent
# 399 fresh
# 101 fri
# 201 friday
# 3230 friend
# 196 friendli
# 316 friendship
# 77 fright
# 301 frighten
# 66 frog
# 624 front
# 62 frontal
# 68 frontier
# 63 fruit
# 339 frustrat
# 284 fu
# 73 fuel
# 114 fulci
# 159 fulfil
# 1783 full
# 83 fuller
# 426 fulli
# 2694 fun
# 156 function
# 121 fund
# 80 fundament
# 114 funer
# 4288 funni
# 173 funnier
# 358 funniest
# 90 furi
# 83 furiou
# 106 furthermor
# 912 futur
# 121 futurist
# 122 fx
# 208 ga
# 70 gabl
# 117 gabriel
# 140 gadget
# 413 gag
# 264 gain
# 96 gal
# 63 galaxi
# 94 gambl
# 1651 game
# 122 gandhi
# 466 gang
# 356 gangster
# 99 gap
# 460 garbag
# 103 garbo
# 177 garden
# 272 gari
# 61 garland
# 110 garner
# 70 gasp
# 133 gate
# 190 gather
# 1216 gave
# 649 gay
# 107 gear
# 83 geek
# 429 gem
# 105 gender
# 282 gene
# 2022 gener
# 63 genet
# 75 geni
# 452 geniu
# 1367 genr
# 122 gentl
# 84 gentleman
# 511 genuin
# 933 georg
# 93 gerard
# 71 gere
# 614 german
# 227 germani
# 85 gestur
# 14141 get
# 62 ghetto
# 666 ghost
# 120 giallo
# 440 giant
# 249 gift
# 93 giggl
# 66 gilbert
# 64 gilliam
# 73 gillian
# 96 gimmick
# 73 gina
# 107 ginger
# 4064 girl
# 684 girlfriend
# 5792 give
# 1849 given
# 451 glad
# 104 glamor
# 85 glanc
# 66 glare
# 238 glass
# 123 glenn
# 214 glimps
# 114 global
# 77 globe
# 154 glori
# 71 glorifi
# 104 gloriou
# 143 glover
# 124 glow
# 9305 go
# 193 goal
# 1271 god
# 137 godfath
# 105 godzilla
# 2441 goe
# 100 goer
# 295 gold
# 123 goldberg
# 63 goldblum
# 259 golden
# 65 goldsworthi
# 754 gone
# 241 gonna
# 15360 good
# 72 goof
# 168 goofi
# 253 gordon
# 1055 gore
# 368 gorgeou
# 235 gori
# 3583 got
# 136 gothic
# 129 gotta
# 286 gotten
# 469 govern
# 270 grab
# 424 grace
# 488 grade
# 137 gradual
# 122 graduat
# 94 graham
# 74 graini
# 319 grand
# 101 grandfath
# 134 grandmoth
# 482 grant
# 442 graphic
# 128 grasp
# 60 grass
# 146 grate
# 244 gratuit
# 228 grave
# 127 gray
# 89 grayson
# 9171 great
# 174 greater
# 745 greatest
# 154 greatli
# 86 greed
# 91 greedi
# 122 greek
# 465 green
# 65 greet
# 83 greg
# 79 gregori
# 251 grew
# 165 grey
# 80 grief
# 118 griffith
# 195 grim
# 74 grin
# 103 grinch
# 249 grip
# 201 gritti
# 63 groan
# 237 gross
# 92 grotesqu
# 459 ground
# 1147 group
# 659 grow
# 252 grown
# 62 growth
# 76 grudg
# 180 gruesom
# 175 guarante
# 265 guard
# 1565 guess
# 206 guest
# 203 guid
# 145 guilt
# 198 guilti
# 71 guin
# 80 guitar
# 872 gun
# 105 gundam
# 60 gunfight
# 66 gunga
# 231 gut
# 4339 guy
# 60 gypo
# 184 ha
# 93 habit
# 140 hack
# 62 hackman
# 77 hackney
# 73 hain
# 594 hair
# 105 hal
# 2094 half
# 173 halfway
# 246 hall
# 244 halloween
# 81 hallucin
# 144 ham
# 129 hamilton
# 147 hamlet
# 152 hammer
# 73 hammi
# 84 han
# 2221 hand
# 62 handicap
# 516 handl
# 237 handsom
# 444 hang
# 245 hank
# 68 hapless
# 3624 happen
# 1151 happi
# 152 happili
# 69 hara
# 2681 hard
# 102 hardcor
# 112 harder
# 180 hardi
# 613 hardli
# 61 harlow
# 121 harm
# 72 harmless
# 70 harold
# 730 harri
# 68 harrison
# 214 harsh
# 109 hart
# 101 hartley
# 107 harvey
# 276 hat
# 1295 hate
# 122 hatr
# 521 haunt
# 139 hawk
# 86 hay
# 108 hbo
# 2075 head
# 72 headach
# 95 heal
# 138 health
# 64 healthi
# 73 heap
# 1050 hear
# 1111 heard
# 1688 heart
# 97 heartbreak
# 75 heartfelt
# 68 heartwarm
# 155 heat
# 355 heaven
# 506 heavi
# 180 heavili
# 222 heck
# 89 heel
# 155 height
# 76 heist
# 391 held
# 152 helen
# 124 helicopt
# 1032 hell
# 90 hello
# 68 helm
# 2828 help
# 80 helpless
# 155 henc
# 424 henri
# 72 hepburn
# 61 her
# 60 herd
# 1389 hero
# 135 heroic
# 353 heroin
# 99 hesit
# 138 heston
# 409 hey
# 342 hidden
# 419 hide
# 103 hideou
# 2174 high
# 289 higher
# 106 highest
# 1147 highli
# 370 highlight
# 66 highway
# 68 hilar
# 1091 hilari
# 397 hill
# 314 hint
# 195 hip
# 168 hippi
# 412 hire
# 569 histor
# 1338 histori
# 64 historian
# 1497 hit
# 210 hitchcock
# 309 hitler
# 74 hk
# 126 ho
# 188 hoffman
# 71 hokey
# 1054 hold
# 543 hole
# 121 holi
# 180 holiday
# 110 holli
# 116 hollow
# 1920 hollywood
# 196 holm
# 67 holocaust
# 153 homag
# 1957 home
# 147 homeless
# 108 homer
# 117 homicid
# 170 homosexu
# 481 honest
# 99 honesti
# 453 honestli
# 191 hong
# 251 honor
# 61 honour
# 196 hood
# 275 hook
# 71 hooker
# 61 hoot
# 123 hop
# 2529 hope
# 102 hopeless
# 74 hopelessli
# 76 hopkin
# 99 hopper
# 78 horn
# 61 horni
# 155 horrend
# 1418 horribl
# 116 horrid
# 171 horrif
# 153 horrifi
# 3717 horror
# 445 hors
# 384 hospit
# 208 host
# 71 hostag
# 62 hostil
# 703 hot
# 412 hotel
# 2171 hour
# 2328 hous
# 91 household
# 72 housewif
# 260 howard
# 3537 howev
# 66 howl
# 67 http
# 141 hudson
# 68 hug
# 1006 huge
# 185 hugh
# 138 huh
# 77 hulk
# 91 hum
# 2262 human
# 106 humbl
# 109 humili
# 1592 humor
# 451 humour
# 300 hundr
# 98 hung
# 77 hungri
# 422 hunt
# 329 hunter
# 514 hurt
# 1105 husband
# 66 huston
# 61 hybrid
# 97 hyde
# 214 hype
# 87 hypnot
# 184 hyster
# 132 ian
# 303 ice
# 194 icon
# 63 id
# 2638 idea
# 209 ideal
# 355 ident
# 207 identifi
# 66 ideolog
# 464 idiot
# 71 idol
# 64 ie
# 565 ignor
# 366 ii
# 135 iii
# 400 ill
# 102 illeg
# 105 illog
# 67 illus
# 160 illustr
# 92 im
# 860 imag
# 186 imageri
# 1547 imagin
# 704 imdb
# 217 imit
# 71 immatur
# 542 immedi
# 163 immens
# 76 immers
# 109 immigr
# 99 immort
# 401 impact
# 109 imperson
# 140 implaus
# 158 impli
# 79 implic
# 1103 import
# 127 importantli
# 76 impos
# 538 imposs
# 1472 impress
# 78 improb
# 371 improv
# 87 improvis
# 79 inabl
# 63 inaccur
# 64 inaccuraci
# 107 inan
# 107 inappropri
# 61 incarn
# 176 incid
# 110 incident
# 2020 includ
# 63 inclus
# 154 incoher
# 125 incompet
# 101 incomprehens
# 127 inconsist
# 88 incorpor
# 62 incorrect
# 124 increas
# 131 increasingli
# 1194 incred
# 722 inde
# 403 independ
# 219 indi
# 179 india
# 527 indian
# 229 indic
# 87 indiffer
# 409 individu
# 146 induc
# 179 indulg
# 447 industri
# 187 inept
# 228 inevit
# 143 inexplic
# 153 infam
# 108 infect
# 104 inferior
# 69 inflict
# 367 influenc
# 69 info
# 603 inform
# 76 ingeni
# 134 ingredi
# 62 ingrid
# 177 inhabit
# 88 inher
# 112 inherit
# 431 initi
# 93 inject
# 72 injur
# 75 injuri
# 76 inmat
# 211 inner
# 609 innoc
# 154 innov
# 339 insan
# 61 insecur
# 130 insert
# 622 insid
# 322 insight
# 72 insipid
# 209 insist
# 167 inspector
# 811 inspir
# 196 instal
# 341 instanc
# 106 instant
# 128 instantli
# 2190 instead
# 155 instinct
# 106 institut
# 69 instruct
# 91 instrument
# 434 insult
# 90 insur
# 178 integr
# 251 intellectu
# 902 intellig
# 479 intend
# 573 intens
# 604 intent
# 288 interact
# 4893 interest
# 69 interestingli
# 88 interior
# 372 intern
# 155 internet
# 293 interpret
# 107 interrupt
# 417 interview
# 100 intim
# 71 intric
# 550 intrigu
# 549 introduc
# 173 introduct
# 79 invad
# 103 invas
# 328 invent
# 137 invest
# 451 investig
# 227 invis
# 252 invit
# 1980 involv
# 93 iran
# 85 iraq
# 115 ireland
# 195 irish
# 414 iron
# 163 ironi
# 90 irrelev
# 341 irrit
# 80 isabel
# 77 ish
# 598 island
# 164 isol
# 67 isra
# 85 israel
# 725 issu
# 153 itali
# 563 italian
# 144 item
# 76 iv
# 945 jack
# 79 jacket
# 243 jacki
# 346 jackson
# 68 jade
# 187 jail
# 164 jake
# 64 jam
# 1070 jame
# 129 jami
# 84 jan
# 662 jane
# 293 japan
# 714 japanes
# 124 jar
# 64 jare
# 331 jason
# 193 jaw
# 161 jay
# 114 jazz
# 121 jealou
# 61 jealousi
# 375 jean
# 64 jedi
# 309 jeff
# 108 jeffrey
# 106 jenni
# 260 jennif
# 142 jeremi
# 190 jerk
# 382 jerri
# 203 jess
# 171 jessica
# 290 jesu
# 142 jet
# 111 jew
# 82 jewel
# 164 jewish
# 62 jill
# 492 jim
# 284 jimmi
# 67 jo
# 302 joan
# 2461 job
# 79 jodi
# 692 joe
# 81 joel
# 128 joey
# 2222 john
# 328 johnni
# 197 johnson
# 377 join
# 1656 joke
# 70 joker
# 187 jon
# 99 jonathan
# 408 jone
# 67 jordan
# 233 joseph
# 83 josh
# 147 journalist
# 460 journey
# 336 joy
# 302 jr
# 64 judd
# 476 judg
# 82 judgment
# 124 judi
# 64 jule
# 230 juli
# 189 julia
# 87 julian
# 60 juliet
# 677 jump
# 90 june
# 204 jungl
# 92 junior
# 195 junk
# 418 justic
# 220 justifi
# 100 justin
# 116 juvenil
# 136 kane
# 79 kansa
# 115 kapoor
# 116 karen
# 78 karl
# 148 karloff
# 301 kate
# 68 kathryn
# 118 kay
# 64 kazan
# 308 keaton
# 70 keen
# 2520 keep
# 88 keith
# 433 kelli
# 124 ken
# 111 kennedi
# 116 kenneth
# 64 kent
# 750 kept
# 289 kevin
# 501 key
# 102 khan
# 587 kick
# 3152 kid
# 63 kiddi
# 74 kidman
# 281 kidnap
# 3701 kill
# 1700 killer
# 209 kim
# 3008 kind
# 275 kinda
# 1037 king
# 98 kingdom
# 60 kinnear
# 114 kirk
# 305 kiss
# 125 kitchen
# 74 kitti
# 73 kline
# 63 knee
# 897 knew
# 156 knife
# 121 knight
# 66 knightley
# 308 knock
# 7514 know
# 304 knowledg
# 1081 known
# 78 kolchak
# 271 kong
# 144 korean
# 133 kubrick
# 128 kudo
# 82 kumar
# 243 kung
# 84 kurosawa
# 149 kurt
# 97 kyle
# 614 la
# 137 lab
# 133 label
# 89 labor
# 1821 lack
# 79 lacklust
# 78 ladder
# 61 laden
# 1145 ladi
# 160 laid
# 255 lake
# 759 lame
# 86 lampoon
# 63 lanc
# 592 land
# 60 landmark
# 205 landscap
# 171 lane
# 90 lang
# 566 languag
# 784 larg
# 143 larger
# 183 larri
# 3158 last
# 1309 late
# 2202 later
# 201 latest
# 97 latin
# 362 latter
# 2926 laugh
# 504 laughabl
# 247 laughter
# 118 launch
# 166 laura
# 123 laurel
# 63 lauren
# 75 laurenc
# 65 lavish
# 609 law
# 111 lawrenc
# 246 lawyer
# 178 lay
# 144 layer
# 187 lazi
# 227 le
# 2684 lead
# 311 leader
# 196 leagu
# 118 lean
# 113 leap
# 1375 learn
# 3112 least
# 66 leather
# 2272 leav
# 76 lectur
# 330 led
# 817 lee
# 2125 left
# 296 leg
# 80 legaci
# 121 legal
# 370 legend
# 192 legendari
# 67 legitim
# 76 leigh
# 111 lemmon
# 99 lena
# 121 lend
# 362 length
# 89 lengthi
# 60 lennon
# 98 leo
# 107 leon
# 111 leonard
# 266 lesbian
# 173 lesli
# 2003 less
# 165 lesser
# 407 lesson
# 72 lester
# 2821 let
# 235 letter
# 1210 level
# 276 lewi
# 64 lex
# 116 li
# 222 liber
# 79 liberti
# 143 librari
# 632 lie
# 6640 life
# 65 lifeless
# 126 lifestyl
# 190 lifetim
# 198 lift
# 1555 light
# 65 lighter
# 398 likabl
# 22799 like
# 89 likewis
# 175 lili
# 542 limit
# 176 lincoln
# 105 linda
# 75 lindsay
# 3459 line
# 66 linear
# 249 liner
# 92 linger
# 198 link
# 205 lion
# 189 lip
# 186 lisa
# 796 list
# 619 listen
# 109 lit
# 556 liter
# 76 literari
# 91 literatur
# 6435 littl
# 64 liu
# 4477 live
# 139 lloyd
# 171 lo
# 311 load
# 72 loath
# 1035 local
# 711 locat
# 337 lock
# 81 logan
# 394 logic
# 72 loi
# 106 lol
# 465 london
# 275 lone
# 77 loneli
# 3540 long
# 477 longer
# 60 longest
# 10051 look
# 445 loos
# 376 lord
# 68 loretta
# 828 lose
# 228 loser
# 298 loss
# 1555 lost
# 4778 lot
# 124 lou
# 438 loud
# 226 loui
# 90 louis
# 222 lousi
# 153 lovabl
# 9027 love
# 688 lover
# 1870 low
# 257 lower
# 92 lowest
# 102 loyal
# 89 loyalti
# 149 luca
# 162 luci
# 67 lucil
# 269 luck
# 258 lucki
# 130 luckili
# 209 ludicr
# 195 lugosi
# 67 lui
# 68 luka
# 259 luke
# 100 lumet
# 93 lundgren
# 91 lure
# 77 lurk
# 78 lush
# 149 lust
# 64 luxuri
# 293 lynch
# 163 lyric
# 61 mabel
# 62 macabr
# 98 macarthur
# 464 machin
# 71 macho
# 102 maci
# 664 mad
# 8362 made
# 111 madonna
# 133 mafia
# 177 magazin
# 106 maggi
# 708 magic
# 66 magician
# 304 magnific
# 94 maid
# 102 mail
# 2283 main
# 393 mainli
# 202 mainstream
# 210 maintain
# 1185 major
# 15207 make
# 657 maker
# 210 makeup
# 727 male
# 109 mall
# 81 malon
# 61 mama
# 6036 man
# 1529 manag
# 121 manhattan
# 6688 mani
# 137 maniac
# 265 manipul
# 90 mankind
# 124 mann
# 575 manner
# 169 mansion
# 90 map
# 151 mar
# 79 marc
# 150 march
# 119 margaret
# 70 margin
# 823 mari
# 175 maria
# 116 marin
# 99 mario
# 86 marion
# 838 mark
# 348 market
# 67 marlon
# 923 marri
# 448 marriag
# 108 marshal
# 73 martha
# 94 marti
# 330 martial
# 96 martian
# 378 martin
# 312 marvel
# 353 mask
# 67 mason
# 254 mass
# 166 massacr
# 210 massiv
# 729 master
# 697 masterpiec
# 62 masterson
# 811 match
# 202 mate
# 827 materi
# 67 mathieu
# 197 matrix
# 247 matt
# 1373 matter
# 156 matthau
# 129 matthew
# 251 matur
# 216 max
# 3392 may
# 2340 mayb
# 72 mayhem
# 102 mayor
# 78 mccoy
# 83 mclaglen
# 64 mcqueen
# 63 meal
# 2961 mean
# 92 meander
# 149 meaning
# 112 meaningless
# 614 meant
# 249 meanwhil
# 169 measur
# 129 meat
# 181 mechan
# 307 media
# 193 medic
# 408 mediocr
# 144 medium
# 1608 meet
# 87 meg
# 119 mel
# 68 melissa
# 95 melodi
# 209 melodrama
# 131 melodramat
# 168 melt
# 879 member
# 714 memor
# 607 memori
# 1915 men
# 238 menac
# 542 mental
# 1545 mention
# 60 mentor
# 112 merci
# 541 mere
# 201 merit
# 72 mermaid
# 83 meryl
# 94 mesmer
# 809 mess
# 966 messag
# 70 messi
# 289 met
# 199 metal
# 141 metaphor
# 206 method
# 193 mexican
# 185 mexico
# 87 meyer
# 199 mgm
# 63 miami
# 62 mice
# 1370 michael
# 237 michel
# 108 mickey
# 319 mid
# 969 middl
# 178 midnight
# 2919 might
# 87 mighti
# 136 miik
# 288 mike
# 133 mild
# 174 mildli
# 115 mildr
# 383 mile
# 464 militari
# 107 milk
# 154 mill
# 170 miller
# 546 million
# 87 millionair
# 67 milo
# 159 min
# 2354 mind
# 155 mindless
# 355 mine
# 219 mini
# 143 minim
# 85 minimum
# 63 miniseri
# 76 minist
# 491 minor
# 77 minu
# 3745 minut
# 127 miracl
# 68 miracul
# 250 mirror
# 170 miscast
# 235 miser
# 97 miseri
# 67 misfortun
# 75 misguid
# 95 mislead
# 2160 miss
# 75 missil
# 303 mission
# 634 mistak
# 108 mistaken
# 96 mistress
# 60 misunderstand
# 65 mitch
# 127 mitchel
# 61 mitchum
# 756 mix
# 104 mixtur
# 84 miyazaki
# 83 mm
# 165 mob
# 69 mobil
# 68 mobster
# 120 mock
# 81 mode
# 401 model
# 74 moder
# 964 modern
# 62 modest
# 122 modesti
# 65 moe
# 69 mol
# 91 molli
# 382 mom
# 2784 moment
# 84 mon
# 2370 money
# 61 monitor
# 128 monk
# 230 monkey
# 93 monologu
# 83 monoton
# 932 monster
# 138 montag
# 97 montana
# 420 month
# 62 monti
# 65 monument
# 458 mood
# 111 moodi
# 302 moon
# 244 moor
# 662 moral
# 75 morbid
# 75 moreov
# 275 morgan
# 87 mormon
# 272 morn
# 197 moron
# 98 morri
# 90 mortal
# 941 mostli
# 1597 mother
# 501 motion
# 466 motiv
# 62 motorcycl
# 70 mount
# 320 mountain
# 168 mous
# 456 mouth
# 2434 move
# 321 movement
# 51696 movi
# 1708 mr
# 350 ms
# 180 mst
# 86 mtv
# 9765 much
# 91 muddl
# 141 multi
# 196 multipl
# 63 mum
# 115 mummi
# 91 mundan
# 145 muppet
# 2102 murder
# 215 murphi
# 81 murray
# 70 muscl
# 103 museum
# 4247 music
# 154 musician
# 137 muslim
# 3250 must
# 98 mutant
# 93 mute
# 61 mutil
# 70 mutual
# 103 myer
# 1416 mysteri
# 113 mystic
# 91 myth
# 74 mytholog
# 208 nail
# 228 naiv
# 437 nake
# 2917 name
# 228 nanci
# 449 narr
# 423 narrat
# 73 narrow
# 70 naschi
# 366 nasti
# 114 natali
# 82 nathan
# 536 nation
# 305 nativ
# 1541 natur
# 76 naughti
# 162 navi
# 304 nazi
# 60 nbc
# 145 nd
# 843 near
# 109 nearbi
# 815 nearli
# 154 neat
# 64 neatli
# 324 necessari
# 180 necessarili
# 166 neck
# 183 ned
# 3378 need
# 162 needless
# 402 neg
# 109 neglect
# 239 neighbor
# 158 neighborhood
# 134 neil
# 68 neill
# 537 neither
# 153 nelson
# 75 nemesi
# 112 neo
# 99 nephew
# 115 nerd
# 119 nerv
# 97 nervou
# 75 net
# 60 netflix
# 236 network
# 69 neurot
# 6484 never
# 236 nevertheless
# 4315 new
# 77 newcom
# 65 newer
# 89 newli
# 79 newman
# 331 news
# 139 newspap
# 1716 next
# 2312 nice
# 92 nichola
# 113 nicholson
# 300 nick
# 87 nicol
# 81 nicola
# 73 niec
# 2293 night
# 66 nightclub
# 426 nightmar
# 64 nina
# 163 nine
# 88 nineti
# 128 ninja
# 100 niro
# 158 nobl
# 462 nobodi
# 120 nod
# 456 noir
# 214 nois
# 75 nolan
# 70 nolt
# 420 nomin
# 898 non
# 1032 none
# 163 nonetheless
# 371 nonsens
# 67 nope
# 82 norm
# 770 normal
# 127 norman
# 213 north
# 67 northern
# 191 nose
# 98 nostalg
# 91 nostalgia
# 293 notabl
# 207 notch
# 1027 note
# 4296 noth
# 793 notic
# 140 notion
# 187 notori
# 86 novak
# 1130 novel
# 167 nowaday
# 446 nowher
# 134 nuanc
# 129 nuclear
# 203 nude
# 596 nuditi
# 95 numb
# 1413 number
# 274 numer
# 85 nun
# 161 nurs
# 162 nut
# 86 nyc
# 368 object
# 73 oblig
# 70 obligatori
# 178 obnoxi
# 181 obscur
# 277 observ
# 488 obsess
# 74 obstacl
# 102 obtain
# 1066 obviou
# 1168 obvious
# 181 occas
# 449 occasion
# 64 occup
# 90 occupi
# 394 occur
# 121 ocean
# 701 odd
# 160 oddli
# 69 off
# 217 offend
# 269 offens
# 1057 offer
# 975 offic
# 188 offici
# 1601 often
# 1450 oh
# 151 oil
# 1017 ok
# 706 okay
# 64 ol
# 4583 old
# 656 older
# 71 oldest
# 248 oliv
# 107 olivi
# 96 olli
# 90 omen
# 62 omin
# 27742 one
# 89 onlin
# 328 onto
# 2103 open
# 276 oper
# 429 opera
# 1056 opinion
# 66 oppon
# 482 opportun
# 167 oppos
# 323 opposit
# 96 oppress
# 62 optimist
# 115 option
# 94 orang
# 62 orchestr
# 1159 order
# 271 ordinari
# 259 organ
# 143 orient
# 4044 origin
# 85 orlean
# 67 orphan
# 96 orson
# 1007 oscar
# 87 othello
# 1598 other
# 670 otherwis
# 116 ought
# 74 out
# 132 outcom
# 66 outdat
# 105 outer
# 178 outfit
# 93 outing
# 72 outlaw
# 80 outlin
# 231 outrag
# 64 outright
# 653 outsid
# 417 outstand
# 168 overact
# 1438 overal
# 199 overcom
# 120 overdon
# 249 overli
# 71 overlong
# 238 overlook
# 115 overr
# 172 overwhelm
# 142 owe
# 98 owen
# 150 own
# 326 owner
# 102 oz
# 1156 pace
# 68 pacif
# 204 pacino
# 386 pack
# 116 packag
# 139 pad
# 466 page
# 358 paid
# 1129 pain
# 549 paint
# 83 painter
# 345 pair
# 127 pal
# 86 palac
# 79 palanc
# 78 pale
# 63 palm
# 110 palma
# 95 paltrow
# 85 pamela
# 189 pan
# 123 panic
# 107 pant
# 281 paper
# 229 par
# 100 parad
# 77 paradis
# 152 parallel
# 77 paramount
# 93 paranoia
# 920 parent
# 405 pari
# 489 park
# 247 parker
# 317 parodi
# 68 parson
# 5258 part
# 668 parti
# 99 partial
# 198 particip
# 737 particular
# 1079 particularli
# 127 partli
# 352 partner
# 968 pass
# 83 passabl
# 79 passag
# 94 passeng
# 449 passion
# 1324 past
# 152 pat
# 247 path
# 490 pathet
# 81 patienc
# 268 patient
# 73 patricia
# 223 patrick
# 99 patriot
# 97 pattern
# 898 paul
# 63 paula
# 133 pauli
# 108 paus
# 76 paxton
# 924 pay
# 67 pc
# 271 peac
# 137 peak
# 103 pearl
# 85 peck
# 66 peer
# 106 pen
# 76 penn
# 80 penni
# 9391 peopl
# 63 pepper
# 161 per
# 83 perceiv
# 96 percept
# 1778 perfect
# 637 perfectli
# 5528 perform
# 1681 perhap
# 85 peril
# 843 period
# 70 perman
# 84 perpetu
# 123 perri
# 3274 person
# 143 persona
# 306 perspect
# 69 persuad
# 95 pervers
# 95 pervert
# 202 pet
# 80 pete
# 855 peter
# 85 petti
# 145 pg
# 90 phantom
# 61 phase
# 65 phenomen
# 71 phenomenon
# 80 phil
# 179 philip
# 145 phillip
# 143 philosoph
# 122 philosophi
# 401 phone
# 90 phoni
# 181 photo
# 395 photograph
# 406 photographi
# 117 phrase
# 536 physic
# 126 piano
# 1078 pick
# 68 pickford
# 1968 pictur
# 154 pie
# 1981 piec
# 117 pierc
# 145 pig
# 247 pile
# 358 pilot
# 129 pin
# 88 pink
# 63 pioneer
# 119 pirat
# 133 pit
# 216 pitch
# 328 piti
# 199 pitt
# 68 pixar
# 3048 place
# 206 plagu
# 584 plain
# 850 plan
# 380 plane
# 534 planet
# 171 plant
# 151 plastic
# 65 plate
# 122 plausibl
# 8732 play
# 62 playboy
# 586 player
# 1253 pleas
# 236 pleasant
# 124 pleasantli
# 370 pleasur
# 655 plenti
# 94 plight
# 92 plod
# 6967 plot
# 645 plu
# 81 pocket
# 74 poe
# 94 poem
# 109 poetic
# 92 poetri
# 156 poignant
# 4239 point
# 519 pointless
# 139 poison
# 105 poke
# 93 pokemon
# 63 poker
# 106 polanski
# 83 pole
# 1105 polic
# 75 policeman
# 82 polici
# 147 polish
# 978 polit
# 118 politician
# 60 polli
# 85 ponder
# 165 pool
# 1899 poor
# 713 poorli
# 524 pop
# 112 popcorn
# 200 popul
# 643 popular
# 368 porn
# 100 porno
# 63 porter
# 143 portion
# 165 portrait
# 1902 portray
# 184 pose
# 76 posey
# 858 posit
# 320 possess
# 1913 possibl
# 600 post
# 201 poster
# 106 pot
# 710 potenti
# 65 potter
# 158 pound
# 96 pour
# 133 poverti
# 214 powel
# 1957 power
# 467 practic
# 291 prais
# 77 prank
# 116 pray
# 316 pre
# 95 preach
# 72 preachi
# 70 preced
# 121 preciou
# 153 precis
# 87 predat
# 104 predecessor
# 1095 predict
# 371 prefer
# 178 pregnant
# 108 prejudic
# 154 premier
# 73 preming
# 747 premis
# 366 prepar
# 80 preposter
# 98 prequel
# 416 presenc
# 1520 present
# 85 preserv
# 283 presid
# 208 press
# 125 pressur
# 80 preston
# 207 presum
# 267 pretend
# 83 pretens
# 294 pretenti
# 3665 pretti
# 218 prevent
# 171 preview
# 630 previou
# 204 previous
# 88 prey
# 335 price
# 86 priceless
# 158 pride
# 262 priest
# 106 primari
# 104 primarili
# 213 prime
# 82 primit
# 317 princ
# 205 princess
# 174 princip
# 105 principl
# 255 print
# 192 prior
# 682 prison
# 293 privat
# 124 prize
# 194 pro
# 2874 probabl
# 2337 problem
# 88 proce
# 191 proceed
# 327 process
# 68 proclaim
# 1871 produc
# 2283 product
# 93 profan
# 92 profess
# 437 profession
# 224 professor
# 62 profil
# 85 profit
# 141 profound
# 379 program
# 95 programm
# 365 progress
# 717 project
# 116 prom
# 107 promin
# 607 promis
# 259 promot
# 60 promptli
# 64 pronounc
# 155 proof
# 157 prop
# 203 propaganda
# 230 proper
# 167 properli
# 98 properti
# 63 propheci
# 68 prophet
# 70 proport
# 79 propos
# 197 prostitut
# 384 protagonist
# 314 protect
# 114 protest
# 188 proud
# 937 prove
# 995 provid
# 88 provoc
# 226 provok
# 71 ps
# 112 pseudo
# 66 psych
# 126 psychiatrist
# 101 psychic
# 263 psycho
# 372 psycholog
# 60 psychologist
# 98 psychopath
# 123 psychot
# 664 public
# 118 publish
# 60 puerto
# 920 pull
# 117 pulp
# 61 pump
# 108 pun
# 289 punch
# 172 punish
# 133 punk
# 146 puppet
# 74 puppi
# 215 purchas
# 733 pure
# 117 purpl
# 567 purpos
# 182 pursu
# 95 pursuit
# 422 push
# 3132 put
# 144 puzzl
# 75 quaid
# 131 qualifi
# 1509 qualiti
# 93 quarter
# 388 queen
# 188 quest
# 1333 question
# 341 quick
# 639 quickli
# 290 quiet
# 76 quietli
# 84 quinn
# 185 quirki
# 3841 quit
# 297 quot
# 104 rabbit
# 495 race
# 194 rachel
# 113 racial
# 153 racism
# 179 racist
# 70 radiat
# 96 radic
# 299 radio
# 162 rage
# 319 rain
# 505 rais
# 69 raj
# 147 ralph
# 76 ram
# 97 rambl
# 116 rambo
# 115 ramon
# 78 rampag
# 239 ran
# 90 randi
# 64 randolph
# 373 random
# 85 randomli
# 333 rang
# 123 ranger
# 274 rank
# 91 rant
# 148 rap
# 559 rape
# 61 rapid
# 62 rapidli
# 96 rapist
# 759 rare
# 199 rat
# 2305 rate
# 2733 rather
# 100 ration
# 75 ratso
# 140 rave
# 181 raw
# 407 ray
# 94 raymond
# 67 razor
# 126 rd
# 558 reach
# 164 react
# 386 reaction
# 2762 read
# 139 reader
# 341 readi
# 4741 real
# 279 realis
# 279 realism
# 842 realist
# 1050 realiti
# 1327 realiz
# 11736 realli
# 84 realm
# 79 rear
# 3206 reason
# 156 rebel
# 286 recal
# 532 receiv
# 1089 recent
# 68 recit
# 351 recogn
# 90 recognis
# 90 recognit
# 76 recogniz
# 2290 recommend
# 576 record
# 124 recov
# 128 recreat
# 101 recruit
# 97 recycl
# 837 red
# 465 redeem
# 153 redempt
# 67 redneck
# 162 reduc
# 71 redund
# 169 reed
# 135 reel
# 133 reev
# 687 refer
# 365 reflect
# 222 refresh
# 345 refus
# 477 regard
# 125 regardless
# 99 region
# 84 regist
# 256 regret
# 295 regular
# 79 rehash
# 78 rehears
# 86 reid
# 89 reign
# 62 reincarn
# 209 reject
# 437 rel
# 737 relat
# 1327 relationship
# 164 relax
# 1921 releas
# 63 relentless
# 186 relev
# 262 reli
# 74 reliabl
# 246 relief
# 323 religi
# 262 religion
# 82 reluct
# 70 remad
# 846 remain
# 686 remak
# 570 remark
# 2070 rememb
# 913 remind
# 214 reminisc
# 359 remot
# 229 remov
# 72 renaiss
# 180 render
# 102 rendit
# 1256 rent
# 228 rental
# 463 repeat
# 119 repeatedli
# 154 repetit
# 349 replac
# 65 replay
# 97 repli
# 452 report
# 420 repres
# 84 represent
# 98 repress
# 69 repris
# 108 repuls
# 219 reput
# 60 request
# 454 requir
# 338 rescu
# 320 research
# 389 resembl
# 111 reserv
# 220 resid
# 180 resist
# 152 resolut
# 131 resolv
# 84 reson
# 146 resort
# 134 resourc
# 917 respect
# 111 respond
# 535 respons
# 1852 rest
# 138 restaur
# 177 restor
# 84 restrain
# 79 restrict
# 1052 result
# 69 resum
# 100 resurrect
# 106 retain
# 186 retard
# 162 retir
# 66 retriev
# 1174 return
# 155 reunion
# 112 reunit
# 751 reveal
# 212 revel
# 555 reveng
# 128 revers
# 2184 review
# 120 reviv
# 100 revolt
# 198 revolut
# 116 revolutionari
# 291 revolv
# 188 reward
# 60 rewrit
# 131 rex
# 130 reynold
# 70 rhyme
# 77 rhythm
# 626 rich
# 937 richard
# 92 richardson
# 105 rick
# 122 rid
# 88 ridden
# 630 ride
# 99 rider
# 1154 ridicul
# 101 rifl
# 3554 right
# 526 ring
# 100 riot
# 576 rip
# 403 rise
# 215 risk
# 80 rita
# 69 ritchi
# 136 ritter
# 81 ritual
# 217 rival
# 344 river
# 118 rivet
# 470 road
# 63 roar
# 356 rob
# 80 robber
# 102 robberi
# 87 robbin
# 1095 robert
# 249 robin
# 102 robinson
# 376 robot
# 157 rochest
# 1058 rock
# 150 rocket
# 97 rocki
# 78 rod
# 373 roger
# 4300 role
# 666 roll
# 81 roller
# 118 roman
# 760 romanc
# 879 romant
# 72 rome
# 118 romero
# 96 romp
# 183 ron
# 60 ronald
# 86 roof
# 67 rooki
# 1050 room
# 111 roommat
# 89 rooney
# 297 root
# 97 rope
# 63 rosario
# 273 rose
# 74 rosemari
# 83 ross
# 68 rot
# 96 roth
# 96 rotten
# 200 rough
# 376 round
# 84 rout
# 276 routin
# 150 row
# 61 rowland
# 228 roy
# 118 royal
# 76 rub
# 91 rubber
# 276 rubbish
# 94 rubi
# 89 rude
# 565 ruin
# 86 rukh
# 482 rule
# 77 rumor
# 2723 run
# 80 runner
# 110 rural
# 331 rush
# 236 russel
# 79 russia
# 342 russian
# 122 ruth
# 111 ruthless
# 224 ryan
# 84 sabrina
# 63 sacrif
# 167 sacrific
# 1108 sad
# 61 saddl
# 138 sadist
# 575 sadli
# 275 safe
# 98 safeti
# 108 saga
# 2196 said
# 88 sailor
# 117 saint
# 255 sake
# 105 sale
# 135 salli
# 65 salman
# 71 salt
# 60 salvat
# 457 sam
# 83 sammi
# 131 samurai
# 220 san
# 81 sand
# 175 sandler
# 98 sandra
# 279 santa
# 98 sappi
# 192 sarah
# 61 sarcast
# 75 sassi
# 293 sat
# 179 satan
# 389 satir
# 416 satisfi
# 222 saturday
# 168 savag
# 1731 save
# 3178 saw
# 7457 say
# 232 scale
# 69 scandal
# 72 scar
# 741 scare
# 144 scarecrow
# 62 scarfac
# 998 scari
# 62 scariest
# 232 scenario
# 10586 scene
# 419 sceneri
# 80 schedul
# 183 scheme
# 70 schlock
# 1732 school
# 658 sci
# 556 scienc
# 120 scientif
# 477 scientist
# 60 scifi
# 137 scoobi
# 77 scoop
# 104 scope
# 1203 score
# 71 scorses
# 84 scotland
# 587 scott
# 93 scottish
# 130 scratch
# 690 scream
# 2799 screen
# 735 screenplay
# 230 screenwrit
# 182 screw
# 3342 script
# 80 scriptwrit
# 101 scroog
# 68 se
# 291 sea
# 165 seagal
# 82 seal
# 263 sean
# 517 search
# 1075 season
# 309 seat
# 2310 second
# 76 secondari
# 104 secondli
# 745 secret
# 147 secretari
# 93 secretli
# 248 section
# 260 secur
# 124 seduc
# 105 seduct
# 14111 see
# 126 seed
# 67 seedi
# 426 seek
# 7220 seem
# 347 seemingli
# 6681 seen
# 396 segment
# 81 seldom
# 199 select
# 1185 self
# 127 selfish
# 414 sell
# 127 seller
# 211 semi
# 65 senat
# 439 send
# 68 senior
# 2416 sens
# 94 sensat
# 103 senseless
# 149 sensibl
# 240 sensit
# 69 sensual
# 395 sent
# 192 sentenc
# 328 sentiment
# 79 sentinel
# 287 separ
# 93 septemb
# 1042 sequel
# 1609 sequenc
# 85 sergeant
# 3420 seri
# 450 serial
# 989 seriou
# 1042 serious
# 615 serv
# 136 servant
# 286 servic
# 85 session
# 4116 set
# 200 settl
# 74 setup
# 360 seven
# 129 seventi
# 1663 sever
# 1726 sex
# 453 sexi
# 1000 sexual
# 62 sg
# 103 sh
# 113 shade
# 318 shadow
# 194 shake
# 298 shakespear
# 83 shaki
# 133 shall
# 273 shallow
# 743 shame
# 81 shanghai
# 273 shape
# 581 share
# 185 shark
# 78 sharon
# 223 sharp
# 72 shatter
# 61 shave
# 100 shaw
# 100 shed
# 247 sheer
# 81 sheet
# 103 shelf
# 80 shell
# 95 shelley
# 61 shelter
# 67 shepherd
# 248 sheriff
# 143 shi
# 70 shield
# 157 shift
# 394 shine
# 446 ship
# 103 shirley
# 162 shirt
# 979 shock
# 83 shoddi
# 176 shoe
# 1115 shoot
# 84 shootout
# 360 shop
# 2020 short
# 77 shortcom
# 66 shorter
# 122 shortli
# 2998 shot
# 157 shoulder
# 156 shout
# 86 shove
# 9878 show
# 162 showcas
# 85 showdown
# 186 shower
# 994 shown
# 70 shred
# 194 shut
# 100 sibl
# 531 sick
# 67 sicken
# 82 sid
# 1490 side
# 127 sidekick
# 63 sidewalk
# 180 sidney
# 396 sight
# 503 sign
# 64 signal
# 264 signific
# 156 silenc
# 475 silent
# 965 silli
# 155 silver
# 996 similar
# 98 similarli
# 87 simmon
# 299 simon
# 1023 simpl
# 1965 simpli
# 91 simplic
# 103 simplist
# 146 simpson
# 85 simultan
# 221 sin
# 246 sinatra
# 2906 sinc
# 196 sincer
# 939 sing
# 353 singer
# 950 singl
# 164 sinist
# 187 sink
# 187 sir
# 93 sirk
# 90 sissi
# 1025 sister
# 1263 sit
# 211 sitcom
# 286 site
# 1188 situat
# 388 six
# 116 sixti
# 201 size
# 75 skeptic
# 131 sketch
# 549 skill
# 260 skin
# 392 skip
# 138 skit
# 98 skull
# 350 sky
# 81 slam
# 227 slap
# 177 slapstick
# 95 slash
# 539 slasher
# 143 slaughter
# 174 slave
# 65 sleaz
# 169 sleazi
# 568 sleep
# 72 sleepwalk
# 125 slice
# 99 slick
# 102 slide
# 140 slight
# 122 slightest
# 541 slightli
# 71 slimi
# 144 slip
# 127 sloppi
# 1207 slow
# 412 slowli
# 96 slug
# 66 smack
# 1648 small
# 105 smaller
# 418 smart
# 132 smash
# 76 smell
# 459 smile
# 496 smith
# 277 smoke
# 132 smooth
# 182 snake
# 98 snap
# 65 snatch
# 142 sneak
# 61 snipe
# 79 sniper
# 97 snl
# 156 snow
# 60 snuff
# 304 soap
# 101 soccer
# 641 social
# 707 societi
# 83 soderbergh
# 301 soft
# 162 sold
# 773 soldier
# 250 sole
# 510 solid
# 108 solo
# 106 solut
# 234 solv
# 299 somebodi
# 69 someday
# 757 somehow
# 2363 someon
# 5123 someth
# 1281 sometim
# 965 somewhat
# 483 somewher
# 1506 son
# 1916 song
# 1222 soon
# 72 sooner
# 62 sophi
# 170 sophist
# 129 soprano
# 107 sore
# 771 sorri
# 64 sorrow
# 1684 sort
# 562 soul
# 2237 sound
# 778 soundtrack
# 80 soup
# 264 sourc
# 472 south
# 180 southern
# 125 soviet
# 71 sox
# 61 soylent
# 799 space
# 83 spacey
# 71 spade
# 85 spain
# 101 span
# 282 spanish
# 149 spare
# 143 spark
# 62 sparkl
# 65 spawn
# 1129 speak
# 97 speci
# 2258 special
# 260 specif
# 64 spectacl
# 250 spectacular
# 264 speech
# 304 speed
# 256 spell
# 828 spend
# 536 spent
# 291 spi
# 77 spice
# 101 spider
# 154 spielberg
# 146 spike
# 62 spill
# 211 spin
# 70 spinal
# 65 spine
# 74 spiral
# 778 spirit
# 163 spiritu
# 113 spit
# 189 spite
# 125 splatter
# 123 splendid
# 191 split
# 92 spock
# 399 spoil
# 976 spoiler
# 91 spoke
# 169 spoken
# 73 spontan
# 242 spoof
# 128 spooki
# 383 sport
# 574 spot
# 63 spray
# 138 spread
# 70 spree
# 162 spring
# 76 springer
# 80 squad
# 139 squar
# 360 st
# 185 stab
# 102 stack
# 112 staff
# 935 stage
# 71 stair
# 84 stake
# 90 stale
# 178 stalk
# 87 stalker
# 91 stallon
# 144 stan
# 1463 stand
# 808 standard
# 76 standout
# 168 stanley
# 161 stanwyck
# 4449 star
# 60 stardom
# 209 stare
# 83 stargat
# 80 stark
# 4166 start
# 88 startl
# 1060 state
# 242 statement
# 67 static
# 379 station
# 265 statu
# 1260 stay
# 74 steadi
# 603 steal
# 99 steam
# 169 steel
# 71 steer
# 102 stellar
# 584 step
# 342 stephen
# 613 stereotyp
# 483 steve
# 335 steven
# 472 stewart
# 650 stick
# 140 stiff
# 5664 still
# 118 stiller
# 95 stilt
# 71 stimul
# 163 stink
# 117 stinker
# 102 stir
# 283 stock
# 115 stole
# 190 stolen
# 181 stomach
# 457 stone
# 133 stood
# 126 stoog
# 1543 stop
# 595 store
# 13168 stori
# 186 storm
# 822 storylin
# 204 storytel
# 869 straight
# 76 straightforward
# 105 strain
# 97 strand
# 1114 strang
# 236 stranger
# 77 stream
# 103 streep
# 968 street
# 152 streisand
# 306 strength
# 148 stress
# 293 stretch
# 129 strictli
# 404 strike
# 195 string
# 213 strip
# 69 strive
# 84 stroke
# 1096 strong
# 133 stronger
# 70 strongest
# 222 strongli
# 128 struck
# 282 structur
# 709 struggl
# 80 stuart
# 350 stuck
# 752 student
# 447 studi
# 698 studio
# 1181 stuff
# 224 stumbl
# 499 stun
# 61 stunningli
# 286 stunt
# 1888 stupid
# 1760 style
# 159 stylish
# 61 stylist
# 66 styliz
# 387 sub
# 938 subject
# 75 sublim
# 68 submit
# 208 subplot
# 167 subsequ
# 230 substanc
# 62 substanti
# 87 substitut
# 61 subtext
# 248 subtitl
# 437 subtl
# 136 subtleti
# 63 subtli
# 60 suburban
# 60 subway
# 167 succe
# 283 succeed
# 1344 success
# 751 suck
# 83 sucker
# 250 sudden
# 538 suddenli
# 91 sue
# 802 suffer
# 93 suffic
# 77 suffici
# 79 sugar
# 771 suggest
# 355 suicid
# 576 suit
# 163 suitabl
# 193 sullivan
# 297 sum
# 65 summar
# 185 summari
# 389 summer
# 200 sun
# 195 sunday
# 77 sung
# 81 sunni
# 117 sunshin
# 501 super
# 671 superb
# 126 superbl
# 143 superfici
# 139 superhero
# 360 superior
# 311 superman
# 208 supernatur
# 124 suppli
# 1505 support
# 1924 suppos
# 365 supposedli
# 72 suprem
# 3100 sure
# 156 surf
# 211 surfac
# 71 surgeri
# 92 surpass
# 2021 surpris
# 466 surprisingli
# 242 surreal
# 391 surround
# 626 surviv
# 186 survivor
# 186 susan
# 519 suspect
# 130 suspend
# 1009 suspens
# 111 suspici
# 77 suspicion
# 81 sustain
# 160 sutherland
# 93 swallow
# 182 swear
# 73 sweat
# 112 swedish
# 80 sweep
# 623 sweet
# 66 swept
# 190 swim
# 147 swing
# 234 switch
# 231 sword
# 329 symbol
# 100 sympath
# 239 sympathet
# 219 sympathi
# 111 synopsi
# 410 system
# 218 tabl
# 72 taboo
# 66 tack
# 83 tacki
# 95 tackl
# 80 tactic
# 97 tad
# 132 tag
# 97 tail
# 6654 take
# 986 taken
# 956 tale
# 1787 talent
# 2159 talk
# 103 talki
# 121 tall
# 130 tame
# 120 tank
# 172 tap
# 369 tape
# 65 tara
# 82 tarantino
# 324 target
# 292 tarzan
# 218 task
# 580 tast
# 77 tasteless
# 95 taught
# 81 tax
# 92 taxi
# 316 taylor
# 136 tea
# 315 teach
# 391 teacher
# 935 team
# 506 tear
# 76 teas
# 82 tech
# 513 technic
# 80 technicolor
# 286 techniqu
# 290 technolog
# 198 ted
# 218 tediou
# 537 teen
# 775 teenag
# 186 teeth
# 932 televis
# 3215 tell
# 81 temper
# 130 templ
# 101 tempt
# 851 ten
# 101 tenant
# 353 tend
# 78 tendenc
# 134 tender
# 157 tens
# 574 tension
# 615 term
# 117 termin
# 132 terri
# 1917 terribl
# 455 terrif
# 219 terrifi
# 143 territori
# 314 terror
# 192 terrorist
# 341 test
# 85 testament
# 212 texa
# 172 text
# 745 th
# 1146 thank
# 345 that
# 1057 theater
# 359 theatr
# 262 theatric
# 1292 theme
# 248 theori
# 345 therefor
# 119 thick
# 158 thief
# 61 thiev
# 368 thin
# 8214 thing
# 8913 think
# 776 third
# 203 thirti
# 254 thoma
# 85 thompson
# 350 thoroughli
# 4566 though
# 3773 thought
# 298 thousand
# 120 thread
# 148 threat
# 290 threaten
# 2297 three
# 112 threw
# 463 thrill
# 1046 thriller
# 159 throat
# 1360 throughout
# 742 throw
# 409 thrown
# 97 thru
# 60 thrust
# 418 thu
# 149 thug
# 182 thumb
# 77 thunderbird
# 72 tick
# 177 ticket
# 377 tie
# 76 tierney
# 109 tiger
# 194 tight
# 213 till
# 309 tim
# 68 timberlak
# 16191 time
# 128 timeless
# 109 timon
# 118 timothi
# 214 tini
# 111 tip
# 459 tire
# 94 tiresom
# 214 titan
# 1793 titl
# 1282 today
# 112 todd
# 65 toe
# 2247 togeth
# 144 toilet
# 67 token
# 63 tokyo
# 1063 told
# 185 toler
# 785 tom
# 117 tomato
# 61 tomb
# 113 tommi
# 77 tomorrow
# 201 ton
# 599 tone
# 178 tongu
# 582 toni
# 96 tonight
# 1100 took
# 146 tool
# 95 tooth
# 1957 top
# 238 topic
# 101 topless
# 119 torment
# 154 torn
# 67 toronto
# 496 tortur
# 134 toss
# 1949 total
# 1284 touch
# 501 tough
# 182 tour
# 91 tourist
# 922 toward
# 144 tower
# 1328 town
# 289 toy
# 106 trace
# 182 traci
# 596 track
# 185 trade
# 103 trademark
# 488 tradit
# 68 traffic
# 387 tragedi
# 376 tragic
# 109 trail
# 479 trailer
# 781 train
# 81 trait
# 75 transcend
# 172 transfer
# 329 transform
# 143 transit
# 291 translat
# 70 transplant
# 117 transport
# 389 trap
# 556 trash
# 100 trashi
# 64 trauma
# 83 traumat
# 577 travel
# 84 travesti
# 241 treasur
# 727 treat
# 246 treatment
# 279 tree
# 267 trek
# 185 tremend
# 92 trend
# 6357 tri
# 217 trial
# 69 triangl
# 107 tribe
# 145 tribut
# 357 trick
# 67 trier
# 72 trigger
# 222 trilog
# 114 trio
# 552 trip
# 78 tripe
# 71 tripl
# 153 trite
# 151 triumph
# 70 trivia
# 60 troma
# 109 troop
# 769 troubl
# 192 truck
# 2333 true
# 1743 truli
# 63 truman
# 382 trust
# 805 truth
# 93 tube
# 343 tune
# 88 tunnel
# 66 turd
# 189 turkey
# 60 turmoil
# 3880 turn
# 123 turner
# 62 turtl
# 2790 tv
# 115 twelv
# 330 twenti
# 387 twice
# 89 twilight
# 210 twin
# 1268 twist
# 6908 two
# 74 tyler
# 1408 type
# 908 typic
# 367 ugli
# 72 uh
# 230 uk
# 769 ultim
# 140 ultra
# 67 uma
# 191 un
# 248 unabl
# 63 unattract
# 86 unawar
# 146 unbear
# 563 unbeliev
# 347 uncl
# 169 uncomfort
# 190 unconvinc
# 82 uncov
# 74 uncut
# 64 undead
# 87 undeni
# 175 underground
# 87 underli
# 68 undermin
# 77 underneath
# 235 underr
# 92 underst
# 2132 understand
# 179 understood
# 64 undertak
# 60 underwat
# 61 underwear
# 73 underworld
# 107 undoubtedli
# 111 uneven
# 253 unexpect
# 79 unexpectedli
# 74 unexplain
# 81 unfair
# 252 unfold
# 149 unforgett
# 1562 unfortun
# 268 unfunni
# 102 unhappi
# 118 uniform
# 65 uniformli
# 84 unimagin
# 161 uninspir
# 243 unintent
# 211 uninterest
# 140 union
# 687 uniqu
# 344 unit
# 592 univers
# 308 unknown
# 85 unleash
# 675 unless
# 934 unlik
# 307 unnecessari
# 88 unorigin
# 121 unpleas
# 95 unpredict
# 82 unravel
# 99 unreal
# 240 unrealist
# 87 unrel
# 83 unsatisfi
# 83 unseen
# 110 unsettl
# 61 unsur
# 63 unsuspect
# 362 unusu
# 119 unwatch
# 277 up
# 132 updat
# 94 uplift
# 859 upon
# 160 upper
# 201 upset
# 204 urban
# 139 urg
# 3794 us
# 164 usa
# 5124 use
# 132 useless
# 162 user
# 83 ustinov
# 1946 usual
# 98 util
# 306 utter
# 454 utterli
# 102 uwe
# 170 vacat
# 74 vader
# 220 vagu
# 63 vain
# 85 valentin
# 82 valid
# 84 valley
# 1004 valu
# 97 valuabl
# 684 vampir
# 509 van
# 81 vanc
# 67 vanessa
# 102 vanish
# 69 vaniti
# 131 vari
# 75 variat
# 194 varieti
# 603 variou
# 104 vast
# 62 vastli
# 150 vega
# 297 vehicl
# 88 vein
# 94 vengeanc
# 67 venom
# 110 ventur
# 82 verbal
# 62 verg
# 119 verhoeven
# 2410 version
# 109 versu
# 78 vet
# 250 veteran
# 310 vh
# 169 via
# 68 vibrant
# 98 vice
# 116 viciou
# 816 victim
# 240 victor
# 98 victori
# 233 victoria
# 62 victorian
# 1866 video
# 192 vietnam
# 2193 view
# 2047 viewer
# 72 viewpoint
# 63 vignett
# 67 vile
# 308 villag
# 927 villain
# 170 vincent
# 1091 violenc
# 560 violent
# 233 virgin
# 94 virginia
# 72 virtu
# 270 virtual
# 140 viru
# 112 visibl
# 375 vision
# 504 visit
# 77 visitor
# 1058 visual
# 86 vital
# 112 vivid
# 60 vividli
# 94 vocal
# 1482 voic
# 111 voight
# 93 volum
# 79 vomit
# 184 von
# 382 vote
# 110 voyag
# 273 vs
# 106 vulgar
# 131 vulner
# 96 wacki
# 77 wagner
# 1400 wait
# 91 waitress
# 266 wake
# 1358 walk
# 142 walken
# 129 walker
# 505 wall
# 117 wallac
# 87 walsh
# 63 walt
# 251 walter
# 246 wander
# 81 wang
# 158 wanna
# 134 wannab
# 6640 want
# 2394 war
# 145 ward
# 67 wardrob
# 60 warhol
# 365 warm
# 86 warmth
# 724 warn
# 200 warner
# 83 warrant
# 117 warren
# 202 warrior
# 156 wash
# 273 washington
# 2229 wast
# 13941 watch
# 311 watchabl
# 75 watcher
# 703 water
# 86 watson
# 306 wave
# 83 wax
# 8830 way
# 243 wayn
# 121 we
# 908 weak
# 62 weaker
# 99 weakest
# 109 wealth
# 153 wealthi
# 316 weapon
# 678 wear
# 62 weari
# 73 weather
# 77 weav
# 123 web
# 126 websit
# 338 wed
# 662 week
# 216 weekend
# 150 weight
# 708 weird
# 268 welcom
# 11042 well
# 99 wendi
# 68 wendigo
# 1463 went
# 273 werewolf
# 477 west
# 798 western
# 100 wet
# 65 whack
# 141 whale
# 85 what
# 734 whatev
# 319 whatsoev
# 99 wheel
# 270 whenev
# 149 wherea
# 856 whether
# 280 whilst
# 93 whine
# 113 whip
# 1551 white
# 202 whoever
# 3080 whole
# 82 wholli
# 97 whoopi
# 71 whore
# 986 whose
# 125 wick
# 368 wide
# 70 widescreen
# 155 widmark
# 200 widow
# 69 wield
# 2140 wife
# 84 wig
# 473 wild
# 152 wilder
# 77 wildli
# 384 will
# 224 willi
# 940 william
# 200 wilson
# 1008 win
# 67 winchest
# 424 wind
# 322 window
# 256 wing
# 271 winner
# 242 winter
# 127 wipe
# 111 wire
# 89 wisdom
# 421 wise
# 1303 wish
# 739 wit
# 423 witch
# 60 witchcraft
# 832 within
# 3268 without
# 279 witti
# 105 wive
# 122 wizard
# 142 wolf
# 2839 woman
# 1827 women
# 3639 wonder
# 61 wonderland
# 101 wont
# 100 woo
# 675 wood
# 332 wooden
# 241 woodi
# 1817 word
# 98 wore
# 7102 work
# 294 worker
# 3979 world
# 99 worm
# 88 worn
# 330 worri
# 1468 wors
# 76 worship
# 2731 worst
# 2280 worth
# 364 worthi
# 128 worthless
# 187 worthwhil
# 12436 would
# 243 wound
# 444 wow
# 230 wrap
# 172 wreck
# 78 wrench
# 125 wrestl
# 66 wrestler
# 81 wretch
# 2096 write
# 1814 writer
# 1616 written
# 1872 wrong
# 574 wrote
# 64 wtf
# 85 ww
# 78 wwe
# 158 wwii
# 71 www
# 105 ya
# 105 yard
# 94 yawn
# 1551 ye
# 462 yeah
# 6878 year
# 75 yearn
# 191 yell
# 113 yellow
# 60 yep
# 119 yesterday
# 2753 yet
# 78 yeti
# 60 yokai
# 812 york
# 3664 young
# 504 younger
# 74 youngest
# 364 youth
# 61 youtub
# 70 zane
# 390 zero
# 85 zizek
# 1331 zombi
# 161 zone
# 71 zoom

# %%
from sklearn.ensemble import RandomForestClassifier

# Initialize a Random Forest classifier with 100 trees
forest = RandomForestClassifier(n_estimators = 100)
forest_tfidf = RandomForestClassifier(n_estimators = 100)

# Fit the forest to the training set, using the bag of words as features 
# and the sentiment labels as the response variable

forest = forest.fit( train_data_features, train["sentiment"] )
forest_tfidf = forest_tfidf.fit( TfIdf_train_data_features, train["sentiment"] )

# %%
test = pd.read_csv("testData.tsv", header=0, delimiter="\t", quoting=3 )

num_test_reviews = test["review"].size
clean_test_reviews = []
stemmed_test_reviews = []

for i in xrange (0, num_test_reviews) : 
    clean_test_reviews.append(review_to_words(test["review"][i]))
    stemmed_test_reviews.append(stem_review(clean_test_reviews[i]))
    
test_data_features = vectorizer.transform(stemmed_test_reviews)
TfIdf_test_data_features = tfidf_transformer.transform(test_data_features)

test_data_features = test_data_features.toarray()
TfIdf_test_data_features = TfIdf_test_data_features.toarray()

result = forest.predict(test_data_features)
result_tfidf = forest_tfidf.predict(TfIdf_test_data_features)

# Copy the results to a pandas dataframe with an "id" column and a "sentiment" column
#output = pd.DataFrame( data={"id":test["id"], "sentiment":result} )
output = pd.DataFrame( data={"id":test["id"], "sentiment":result_tfidf} )

# Use pandas to write the comma-separated output file
#output.to_csv( "Bag_of_Words_model.csv", index=False, quoting=3 )
output.to_csv( "Bag_of_Words_model_withStemmingAndTfIdf.csv", index=False, quoting=3 )
